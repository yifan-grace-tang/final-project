# %% [markdown]
# ## __Protein Function Prediction Leveraging Sequence and Structure Information__
#
# > __Author:__ Grace Tang
#
# > __Edited:__ `04.24.25`
#
# > __Runtime:__ `A100`
#
# ---

# %% [markdown]
# #### __Description__
#
# Predicting the functions of proteins is an essential problem in the study of proteins. Many previous works developed computational methods that utilize protein sequence information to predict protein functions. With the advancement of `AlphaFold2`, accurate protein structure data has been available for hundreds of millions of proteins.
#
# Incorporating structure information should be able to further boost the performance of protein function prediction methods. There are several potential ways to utilize the structure information: use computer-vision-like models to extract information from contact maps; use graph neural networks to encode 3D structures; use pretrained protein structure model (e.g., `ESM-IF`).
#
# In addition, with the advancement of LLMs, the text annotations of proteins can also be leveraged as an extra information source for protein function prediction, e.g., use LLM as encoder to encode the text annotations of proteins. Utilizing the information from sequence, structure, and text annotations, we can develop a model that accurately predicts protein functions.
#
# __Using a subset of the dataset used for [DeepFRI](https://github.com/flatironinstitute/DeepFRI) (a similar protein function prediction model) we aim to coallesce sequence data and structure data to predict protein function in the form of [EC Numbers](https://en.wikipedia.org/wiki/Enzyme_Commission_number).__
#
# [[1]](ttps://www.biorxiv.org/content/10.1101/2022.11.29.518451v1), [[2]](https://www.nature.com/articles/s42003-024-07359-z), [[3]](https://www.nature.com/articles/s41467-021-23303-9), [[4]](https://www.biorxiv.org/content/10.1101/2024.05.14.594226v1 )

# %% [markdown]
# #### __Methodology__
#
# > _This section relies on having_ `annotations.tsv`, `train.txt`, `validation.txt`, _and_ `sequences.fasta` _in your runtime_
#
# > _While not strictly necessary, we **highly** recommend importing a_ `structures.zip` _into your runtime as well with all the structure information - this will greatly assist the computation time. Even better if you have a_  `cache.zip` _with all pre-computed pytorch vectors that will assist greatly!_

# %%
# !ls -lh structures.zip
# !unzip structures.zip -d structures
# Out:
# -rw-r--r-- 1 root root 94M Apr 25 15:37 structures.zip
# Archive:  structures.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of structures.zip or
#         structures.zip.zip, and cannot find structures.zip.ZIP, period.

# %%
# !pip install torch-geometric
# !pip install transformers biopython scipy
# Out:
# Collecting torch-geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (2025.1.31)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.7 MB/s eta 0:00:00
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.6.1
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.14.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 44.5 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %%
import os
import pandas as pd
import re
import numpy as np
import requests

import torch
from torch.utils.data import Dataset
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.nn import GCNConv, global_mean_pool
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence
import torch.optim as optim
from torch.serialization import add_safe_globals
from torch_geometric.data import Data
from torch_geometric.data.data import DataEdgeAttr, DataTensorAttr
from torch_geometric.data.storage import GlobalStorage

from transformers import BertTokenizer, BertModel

from Bio.PDB import MMCIFParser

from scipy.spatial.distance import pdist, squareform

from sklearn.metrics import precision_score, recall_score, f1_score

add_safe_globals([Data, DataEdgeAttr, DataTensorAttr, GlobalStorage])

# %% [markdown]
# We start by defining some utility functions that help parse the input data into a representation that can be fed into our downstream `Dataset` classes.

# %%
def parse_fasta(path):
    seqs = {}
    with open(path) as f:
        curr, lines = None, []
        for line in f:
            if line.startswith('>'):
                if curr:
                    seqs[curr] = ''.join(lines)
                curr = line[1:].split()[0]
                lines = []
            else:
                lines.append(line.strip())
        if curr:
            seqs[curr] = ''.join(lines)
    return seqs

def parse_annotations(path):
    ann_map, all_ec = {}, set()
    with open(path) as f:
        for ln in f:
            if ln.startswith('### PDB-chain'):
                break
        for ln in f:
            if not ln.strip() or ln.startswith('#'): continue
            pid, ecs = ln.strip().split('\t')
            ec_list = [e.strip() for e in ecs.split(',') if e.strip()]
            ann_map[pid] = ec_list
            all_ec.update(ec_list)
    classes = sorted(all_ec)
    return ann_map, classes

def fetch_cif(pdb_chain, out_dir="structures"):
    pdb_id, chain = pdb_chain.split('-')
    os.makedirs(out_dir, exist_ok=True)
    local_path = os.path.join(out_dir, f"{pdb_chain}.cif")
    if not os.path.exists(local_path):
        url = f"https://files.rcsb.org/download/{pdb_id}.cif"
        resp = requests.get(url)
        resp.raise_for_status()

        with open(local_path, "wb") as f:
            f.write(resp.content)
    return local_path

def build_df(ids, seqs, ann_map, classes):
    rows = []
    for pid in ids:
        seq = seqs.get(pid, '')
        if not seq:
            print(f"Warning: {pid} not found")
            continue
        labels = [1 if ec in ann_map.get(pid, []) else 0 for ec in classes]
        rows.append({'id': pid, 'sequence': seq, 'labels': labels})
    return pd.DataFrame(rows)

# %% [markdown]
# Next we read the `ids` from the `train.txt` and `validation.txt` to perform our _splitting_ into a train and validation dataset.

# %%
train_ids = [l.strip() for l in open('train.txt') if l.strip()]
val_ids   = [l.strip() for l in open('validation.txt') if l.strip()]
seqs_map  = parse_fasta('sequences.fasta')
ann_map, classes = parse_annotations('annotations.tsv')

# %% [markdown]
# This `Dataset` class feeds each protein through two parallel pipelines — sequence and structure — and returns a single `torch_geometric.data.Data` object per example for graph‐based training.
#
# 1. **Structure Fetching:** Given an ID like `4PR3-A`, it downloads the corresponding `mmCIF` file from `RCSB` if not already cached. Uses Biopython’s `PDBParser` to extract all Cα atom coordinates for the specified chain.
#
# 2. **Graph Construction:** Builds an undirected residue‐level graph by connecting any two Cα atoms within 8 Å.  Encodes edge weights as the inverse distance (`1/d`) to reflect spatial proximity.
#
# 3. **Node Features:** Represents each residue by a 20‐dimensional one-hot vector (one position per standard amino acid). Ensures that non-standard letters (U, Z, O, B) are mapped to “X” and treated uniformly.
#
# 4. **`ProtBert` Embedding** Cleans and “space-separates” the amino-acid string for `Rostlab/prot_bert`.  Tokenizes, pads/truncates, and runs the model in `eval()` mode to get the last hidden states.  Applies mean-pooling (masking out padding) to produce a fixed‐size (1024-dim) global embedding.
#
# 5. **Label Vector:** Builds a multi-hot target vector for all EC classes based on `annotations.tsv`.
#
# 6. **Output**
#    - Returns a `Data` object with fields:
#      - `x`: `[L, 20]` residue features
#      - `edge_index`: `[2, E]` graph connectivity
#      - `edge_attr`: `[E, 1]` distance weights
#      - `seq_emb`: `[1024]` `ProtBert` fingerprint
#      - `y`: `[num_ec]` multi-hot EC labels

# %%
# !rm -rf structures/*
# !rm -rf cache/*

# %%
class ProteinDataset(Dataset):
    def __init__(self, ids, seqs_map, ann_map, classes,
                 max_length=512, device=None, ca_cutoff=8.0,
                 pdb_dir="structures"):
        self.ids      = ids
        self.seqs_map = seqs_map
        self.labels   = {
            pid: torch.tensor([1 if ec in ann_map.get(pid, []) else 0
                               for ec in classes], dtype=torch.float)
            for pid in ids
        }
        self.classes = classes
        self.max_length = max_length
        self.device = device or torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.ca_cutoff = ca_cutoff
        self.pdb_dir = pdb_dir

        self.tokenizer = BertTokenizer.from_pretrained("Rostlab/prot_bert", do_lower_case=False)
        self.bert      = BertModel.from_pretrained("Rostlab/prot_bert").to(self.device).eval()

        self.parser = MMCIFParser(QUIET=True)

        aa_list = list("ACDEFGHIKLMNPQRSTVWY")
        self.aa2idx = {aa:i for i, aa in enumerate(aa_list)}
        self.aa2idx["X"] = len(self.aa2idx)   # now maps "X" to index 20
        self.num_tokens = len(self.aa2idx)

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        pid = self.ids[idx]
        cache_path = os.path.join("cache", f"{pid}.pt")

        if os.path.exists(cache_path):
            return torch.load(cache_path)

        seq = self.seqs_map[pid].upper()
        clean = re.sub(r"[^ACDEFGHIKLMNPQRSTVWY]", "X", seq)
        spaced = " ".join(clean)

        enc = self.tokenizer(
            spaced, padding="max_length", truncation=True,
            max_length=self.max_length, return_tensors="pt"
        )
        input_ids = enc["input_ids"].to(self.device)
        attention_mask = enc["attention_mask"].to(self.device)

        with torch.no_grad():
            out = self.bert(input_ids=input_ids, attention_mask=attention_mask)
            last_hidden = out.last_hidden_state
            mask = attention_mask.unsqueeze(-1).float()
            seq_emb = (last_hidden * mask).sum(1) / mask.sum(1)
            seq_emb = seq_emb.squeeze(0).cpu()

        cif_path = fetch_cif(pid, out_dir=self.pdb_dir)
        struct = self.parser.get_structure(pid, cif_path)

        ca_coords = []
        chain_id = pid.split("-")[1]
        for model in struct:
            for chain in model:
                if chain.id == chain_id:
                    for res in chain:
                        if "CA" in res:
                            ca_coords.append(res["CA"].get_coord())
        coords = np.array(ca_coords)

        dmat = squareform(pdist(coords))
        row, col = np.where((dmat < self.ca_cutoff) & (dmat > 0))
        edge_index = torch.tensor([row, col], dtype=torch.long)
        edge_attr = torch.tensor((1.0 / dmat[row, col])[:, None], dtype=torch.float)

        feats = []
        for aa in clean:
            vec = np.zeros(self.num_tokens, dtype=float)
            vec[self.aa2idx.get(aa, self.aa2idx["X"])] = 1.0
            feats.append(vec)
        x = torch.tensor(feats, dtype=torch.float)

        data = Data(
            x=x,
            edge_index=edge_index,
            edge_attr=edge_attr,
            seq_emb=seq_emb,
            y=self.labels[pid]
        )

        os.makedirs("cache", exist_ok=True)
        torch.save(data, cache_path)
        return data

# %% [markdown]
# Using our `Dataset` class now we can input our training and validation data and define some `DataLoaders` to be used by our chosen model.
#
# > We are leveraging a `df_train_mini` subset for faster development for our final model we will use the _full_ training set.

# %%
df_train_mini = train_ids[:1000]

train_ds = ProteinDataset(df_train_mini, seqs_map, ann_map, classes, pdb_dir='structures')
val_ds   = ProteinDataset(val_ids,       seqs_map, ann_map, classes, pdb_dir='structures')

train_loader = GeometricDataLoader(train_ds, batch_size=16, shuffle=True)
val_loader   = GeometricDataLoader(val_ds,   batch_size=16)

# %% [markdown]
# This `ConvClassifer` ingests the `Data` objects produced by `ProteinDataset` and fuses structure and sequence information to predict one or more EC numbers.
#
# 1. **Structure Branch (GCN)**
#    - **GCNConv(20 → 128)** + ReLU
#    - **GCNConv(128 → 128)** + ReLU
#    - **Global Mean Pooling** over residues → a 128-dim graph embedding
#
# 2. **Sequence Branch (MLP)**
#    - **Linear(1024 → 128)** + ReLU
#    - Takes the `ProtBert` pooled embedding and projects it down to 128 dims
#
# 3. **Fusion**
#    - **Concatenate** the 128-dim GCN output and 128-dim MLP output → 256-dim vector
#    - **MLP Head**: Linear(256 → 256) + ReLU + Dropout(0.1) + Linear(256 → `num_ec`)
#    - Outputs one raw logit per EC class
#
# 4. **Training Details**
#    - **Loss**: `BCEWithLogitsLoss` for multi-label classification
#    - **Optimizer**: AdamW with `lr=1e-3`, `weight_decay=1e-5`
#    - **DataLoader**: uses `torch_geometric.loader.DataLoader` to batch graphs

# %%
class ConvClassifier(nn.Module):
    def __init__(self, seq_emb_dim, node_feat_dim, gcn_hidden, num_classes):
        super().__init__()
        self.seq_mlp = nn.Sequential(
            nn.Linear(seq_emb_dim, gcn_hidden),  # was backward before
            nn.ReLU()
        )

        self.conv1 = GCNConv(node_feat_dim, gcn_hidden)
        self.conv2 = GCNConv(gcn_hidden,      gcn_hidden)

        self.classifier = nn.Sequential(
            nn.Linear(2 * gcn_hidden, 256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_classes)
        )

    def forward(self, data):
        x, edge_index, edge_attr, batch = (
            data.x, data.edge_index, data.edge_attr, data.batch
        )

        edge_index = edge_index.clamp(0, x.size(0) - 1)

        h = self.conv1(x, edge_index, edge_weight=edge_attr.squeeze())
        h = torch.relu(h)
        h = self.conv2(h, edge_index, edge_weight=edge_attr.squeeze())
        h = torch.relu(h)
        gcn_emb = global_mean_pool(h, batch)  # → [B, gcn_hidden]

        seq_emb_raw = data.seq_emb             # [B, seq_emb_dim]
        B = gcn_emb.size(0)
        seq_emb = seq_emb_raw.view(B, -1).to(gcn_emb.device)

        seq_emb = self.seq_mlp(seq_emb)        # → [B, gcn_hidden]

        comb = torch.cat([gcn_emb, seq_emb], dim=1)  # → [B, 256]
        return self.classifier(comb)

# %%
example   = train_ds[0]
seq_dim   = example.seq_emb.shape[0]
node_dim  = example.x.shape[1]

print(example)

model = ConvClassifier(seq_emb_dim=seq_dim,
                      node_feat_dim=node_dim,
                      gcn_hidden=128,
                      num_classes=len(classes)).to(torch.device('cuda'))
opt   = torch.optim.AdamW(model.parameters(), lr=1e-3)
crit  = nn.BCEWithLogitsLoss()
# Out:
# Data(x=[145, 21], edge_index=[2, 1294], edge_attr=[1294, 1], y=[538], seq_emb=[1024])

# %%
num_classes = len(classes)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for epoch in range(1, 11):
    model.train()
    total_loss = 0
    for batch in train_loader:
        batch = batch.to(device)
        logits = model(batch)                           # [B, num_classes]
        labels = batch.y.view(logits.size())            # reshape to [B, num_classes]
        loss = crit(logits, labels)
        opt.zero_grad(); loss.backward(); opt.step()
        total_loss += loss.item() * batch.num_graphs
    print(f"Epoch {epoch} Train Loss: {total_loss/len(train_ds):.4f}")

    model.eval()
    all_preds, all_targs = [], []
    with torch.no_grad():
        for batch in val_loader:
            batch = batch.to(device)
            probs = torch.sigmoid(model(batch)).cpu()
            preds = (probs > 0.5).int()
            targs = batch.y.view(probs.size())          # [B, num_classes]
            all_preds.append(preds)
            all_targs.append(targs)
    preds = torch.vstack(all_preds).numpy()
    targs = torch.vstack(all_targs).cpu().numpy()
    print("Val P, R, F1=",
          precision_score(targs, preds, average='micro', zero_division=0),
          recall_score(targs, preds, average='micro', zero_division=0),
          f1_score(targs, preds, average='micro', zero_division=0))
# Out:
# Epoch 1 Train Loss: 0.1877
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 2 Train Loss: 0.0205
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 3 Train Loss: 0.0190
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 4 Train Loss: 0.0187
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 5 Train Loss: 0.0186
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 6 Train Loss: 0.0185
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 7 Train Loss: 0.0184
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 8 Train Loss: 0.0182
# Val P, R, F1= 0.0 0.0 0.0
# Epoch 9 Train Loss: 0.0179
# Val P, R, F1= 0.5 0.0003380662609871535 0.0006756756756756757
# Epoch 10 Train Loss: 0.0176
# Val P, R, F1= 1.0 0.0003380662609871535 0.0006759040216289286

# %%
def find_best_thresholds_per_ec(y_true, y_probs, metric='f1'):
    thresholds = np.linspace(0.1, 0.9, 81)
    best_thresholds = []

    for i in range(y_true.shape[1]):
        best_score = -1
        best_t = 0.5
        for t in thresholds:
            preds = (y_probs[:, i] >= t).astype(int)
            if metric == 'f1':
                score = f1_score(y_true[:, i], preds, zero_division=0)
            elif metric == 'precision':
                score = precision_score(y_true[:, i], preds)
            elif metric == 'recall':
                score = recall_score(y_true[:, i], preds)
            if score > best_score:
                best_score = score
                best_t = t
        best_thresholds.append(best_t)

    return np.array(best_thresholds)

model.eval()
all_true, all_pred = [], []
with torch.no_grad():
    for seqs, labs in val_loader:
        seqs = seqs.to(device)
        logits = model(seqs)
        probs  = torch.sigmoid(logits).cpu()
        all_true.append(labs)
        all_pred.append((probs > 0.5).int())

true = torch.cat(all_true, dim=0)
pred = torch.cat(all_pred, dim=0)

rows = []
for pid, trow, prow in zip(val_ids, true, pred):
    true_ecs = [c for c, flag in zip(classes, trow) if flag]
    pred_ecs = [c for c, flag in zip(classes, prow) if flag]
    rows.append({
        'strain': pid,
        'validation EC class': ';'.join(true_ecs) or '-',
        'predicted': ';'.join(pred_ecs) or '-'
    })

results_df = pd.DataFrame(rows, columns=['strain', 'validation EC class', 'predicted'])
print(results_df)

# %% [markdown]
# For faster future operations save the `structures/` folder as a zip-file to "pre-conpute" embeddings for subsequent runs.

# %%
# !zip -r structures.zip structures
# !zip -r cache.zip cache
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: structures/3IDE-A.cif (deflated 73%)
#   adding: structures/4IJX-A.cif (deflated 73%)
#   adding: structures/2H9E-L.cif (deflated 74%)
#   adding: structures/4PEY-A.cif (deflated 73%)
#   adding: structures/1QU5-A.cif (deflated 78%)
#   adding: structures/6NVQ-C.cif (deflated 73%)
#   adding: structures/3SPL-A.cif (deflated 76%)
#   adding: structures/1Z8R-A.cif (deflated 78%)
#   adding: structures/4OML-A.cif (deflated 73%)
#   adding: structures/6QQR-A.cif (deflated 73%)
#   adding: structures/1O58-A.cif (deflated 75%)
#   adding: structures/5DA1-A.cif (deflated 75%)
#   adding: structures/6I5Z-A.cif (deflated 76%)
#   adding: structures/2YR3-A.cif (deflated 77%)
#   adding: structures/5U0M-A.cif (deflated 72%)
#   adding: structures/3MBR-X.cif (deflated 73%)
#   adding: structures/4IWS-A.cif (deflated 73%)
#   adding: structures/1RJD-A.cif (deflated 76%)
#   adding: structures/2VQY-A.cif (deflated 75%)
#   adding: structures/5F13-A.cif (deflated 74%)
#   adding: structures/6P44-A.cif (deflated 75%)
#   adding: structures/1C7K-A.cif (deflated 74%)
#   adding: structures/2LAA-A.cif (deflated 78%)
#   adding: structures/3WBH-A.cif (deflated 75%)
#   adding: structures/3CQ9-A.cif (deflated 75%)
#   adding: structures/1Z8Y-A.cif (deflated 75%)
#   adding: structures/4KA7-A.cif (deflated 74%)
#   adding: structures/4GWN-A.cif (deflated 72%)
#   adding: structures/3TKU-A.cif (deflated 73%)
#   adding: structures/6TVP-A.cif (deflated 73%)
#   adding: structures/3I4K-A.cif (deflated 76%)
#   adding: structures/2DJ2-A.cif (deflated 78%)
#   adding: structures/3Q98-A.cif (deflated 73%)
#   adding: structures/7BST-D.cif (deflated 82%)
#   adding: structures/2RMC-A.cif (deflated 76%)
#   adding: structures/3WH9-A.cif (deflated 76%)
#   adding: structures/3T72-o.cif (deflated 77%)
#   adding: structures/3PFC-A.cif (deflated 73%)
#   adding: structures/5CA8-A.cif (deflated 74%)
#   adding: structures/4TN6-A.cif (deflated 73%)
#   adding: structures/6MAI-A.cif (deflated 73%)
#   adding: structures/3K8Z-A.cif (deflated 75%)
#   adding: structures/3FDD-A.cif (deflated 75%)
#   adding: structures/3TQZ-A.cif (deflated 73%)
#   adding: structures/1H4P-A.cif (deflated 75%)
#   adding: structures/5WHX-A.cif (deflated 74%)
#   adding: structures/2JZA-A.cif (deflated 75%)
#   adding: structures/4OC6-B.cif (deflated 72%)
#   adding: structures/3HP0-A.cif (deflated 75%)
#   adding: structures/3AHX-A.cif (deflated 75%)
#   adding: structures/1GMI-A.cif (deflated 75%)
#   adding: structures/2KIE-A.cif (deflated 78%)
#   adding: structures/1GLD-G.cif (deflated 75%)
#   adding: structures/1T4N-A.cif (deflated 78%)
#   adding: structures/3K2Q-A.cif (deflated 75%)
#   adding: structures/1NYE-A.cif (deflated 74%)
#   adding: structures/3LPA-A.cif (deflated 73%)
#   adding: structures/4ZZV-A.cif (deflated 76%)
#   adding: structures/3W3S-A.cif (deflated 73%)
#   adding: structures/1WH1-A.cif (deflated 77%)
#   adding: structures/6H3C-E.cif (deflated 79%)
#   adding: structures/5K0Z-A.cif (deflated 75%)
#   adding: structures/2VOY-J.cif (deflated 75%)
#   adding: structures/5UB9-A.cif (deflated 74%)
#   adding: structures/2XKR-A.cif (deflated 75%)
#   adding: structures/5VLB-A.cif (deflated 74%)
#   adding: structures/2F8A-A.cif (deflated 75%)
#   adding: structures/1JEG-A.cif (deflated 77%)
#   adding: structures/6XTY-4.cif (deflated 78%)
#   adding: structures/2YVW-A.cif (deflated 74%)
#   adding: structures/4FX7-A.cif (deflated 73%)
#   adding: structures/2JRZ-A.cif (deflated 78%)
#   adding: structures/2PMN-X.cif (deflated 75%)
#   adding: structures/2HZE-A.cif (deflated 75%)
#   adding: structures/3TQK-A.cif (deflated 73%)
#   adding: structures/4ZYN-A.cif (deflated 73%)
#   adding: structures/6N9M-A.cif (deflated 75%)
#   adding: structures/4ZO0-A.cif (deflated 75%)
#   adding: structures/5J0A-A.cif (deflated 75%)
#   adding: structures/2WEF-A.cif (deflated 76%)
#   adding: structures/2LGO-A.cif (deflated 75%)
#   adding: structures/4A2F-A.cif (deflated 75%)
#   adding: structures/4AXK-A.cif (deflated 74%)
#   adding: structures/1F75-A.cif (deflated 74%)
#   adding: structures/4KZF-A.cif (deflated 74%)
#   adding: structures/1R3U-A.cif (deflated 75%)
#   adding: structures/1AOR-A.cif (deflated 75%)
#   adding: structures/1OPR-A.cif (deflated 75%)
#   adding: structures/6FK4-A.cif (deflated 74%)
#   adding: structures/3V1X-A.cif (deflated 75%)
#   adding: structures/5XLL-A.cif (deflated 73%)
#   adding: structures/4GC9-A.cif (deflated 74%)
#   adding: structures/2VU9-A.cif (deflated 75%)
#   adding: structures/2KUO-A.cif (deflated 78%)
#   adding: structures/1QRL-A.cif (deflated 74%)
#   adding: structures/4ADS-G.cif (deflated 73%)
#   adding: structures/1PG5-A.cif (deflated 74%)
#   adding: structures/4YLY-A.cif (deflated 75%)
#   adding: structures/1TED-A.cif (deflated 75%)
#   adding: structures/2GQC-A.cif (deflated 77%)
#   adding: structures/6HIX-BZ.cif (deflated 78%)
#   adding: structures/2D3T-A.cif (deflated 77%)
#   adding: structures/1VK3-A.cif (deflated 74%)
#   adding: structures/6N64-A.cif (deflated 73%)
#   adding: structures/1E60-A.cif (deflated 76%)
#   adding: structures/1IYX-A.cif (deflated 75%)
#   adding: structures/3J5V-a.cif (deflated 75%)
#   adding: structures/4K33-A.cif (deflated 74%)
#   adding: structures/5SZG-A.cif (deflated 75%)
#   adding: structures/4HDD-A.cif (deflated 74%)
#   adding: structures/2EQA-A.cif (deflated 75%)
#   adding: structures/4C1S-A.cif (deflated 75%)
#   adding: structures/1AOM-A.cif (deflated 76%)
#   adding: structures/1V6A-A.cif (deflated 75%)
#   adding: structures/6U0M-3.cif (deflated 78%)
#   adding: structures/4EXP-X.cif (deflated 74%)
#   adding: structures/2A30-A.cif (deflated 76%)
#   adding: structures/1ORD-A.cif (deflated 78%)
#   adding: structures/3VCO-A.cif (deflated 72%)
#   adding: structures/1VLP-A.cif (deflated 76%)
#   adding: structures/3CQY-A.cif (deflated 75%)
#   adding: structures/4NV4-A.cif (deflated 73%)
#   adding: structures/4L2H-A.cif (deflated 74%)
#   adding: structures/2Q0V-A.cif (deflated 75%)
#   adding: structures/1XHO-A.cif (deflated 75%)
#   adding: structures/5XWD-A.cif (deflated 75%)
#   adding: structures/6PEX-A.cif (deflated 75%)
#   adding: structures/5WKM-A.cif (deflated 74%)
#   adding: structures/3LIB-A.cif (deflated 76%)
#   adding: structures/2R4U-A.cif (deflated 75%)
#   adding: structures/3JB4-A.cif (deflated 74%)
#   adding: structures/1DIA-A.cif (deflated 75%)
#   adding: structures/3G1U-A.cif (deflated 76%)
#   adding: structures/6GIQ-E.cif (deflated 79%)
#   adding: structures/5LNX-A.cif (deflated 76%)
#   adding: structures/2WIO-A.cif (deflated 75%)
#   adding: structures/4OZY-A.cif (deflated 72%)
#   adding: structures/3IU0-A.cif (deflated 75%)
#   adding: structures/4XDY-A.cif (deflated 75%)
#   adding: structures/3EEI-A.cif (deflated 76%)
#   adding: structures/3M6U-A.cif (deflated 74%)
#   adding: structures/6HMS-A.cif (deflated 76%)
#   adding: structures/1JS4-A.cif (deflated 76%)
#   adding: structures/2GWD-A.cif (deflated 75%)
#   adding: structures/3B1F-A.cif (deflated 74%)
#   adding: structures/3L4Y-A.cif (deflated 75%)
#   adding: structures/5MVI-E.cif (deflated 76%)
#   adding: structures/2QVG-A.cif (deflated 75%)
#   adding: structures/4MKS-A.cif (deflated 75%)
#   adding: structures/6JOG-A.cif (deflated 75%)
#   adding: structures/5K8S-A.cif (deflated 74%)
#   adding: structures/2BL0-B.cif (deflated 75%)
#   adding: structures/2YXE-A.cif (deflated 75%)
#   adding: structures/5AR8-A.cif (deflated 74%)
#   adding: structures/4LH8-A.cif (deflated 75%)
#   adding: structures/6C3R-A.cif (deflated 73%)
#   adding: structures/6NB2-A.cif (deflated 73%)
#   adding: structures/1UB7-A.cif (deflated 75%)
#   adding: structures/4CHL-A.cif (deflated 73%)
#   adding: structures/6D9Q-A.cif (deflated 74%)
#   adding: structures/5DV2-A.cif (deflated 73%)
#   adding: structures/1DIH-A.cif (deflated 74%)
#   adding: structures/2OU7-A.cif (deflated 76%)
#   adding: structures/3UWO-A.cif (deflated 75%)
#   adding: structures/4GCZ-A.cif (deflated 73%)
#   adding: structures/3TIW-A.cif (deflated 73%)
#   adding: structures/2Z04-A.cif (deflated 75%)
#   adding: structures/4ZZ5-A.cif (deflated 75%)
#   adding: structures/2ONJ-A.cif (deflated 78%)
#   adding: structures/4IX8-A.cif (deflated 75%)
#   adding: structures/5KKB-A.cif (deflated 74%)
#   adding: structures/6OD8-A.cif (deflated 73%)
#   adding: structures/2PB7-A.cif (deflated 74%)
#   adding: structures/3E9N-A.cif (deflated 75%)
#   adding: structures/3E96-A.cif (deflated 75%)
#   adding: structures/3LAX-A.cif (deflated 73%)
#   adding: structures/4FR4-A.cif (deflated 73%)
#   adding: structures/5LPV-A.cif (deflated 73%)
#   adding: structures/3H0P-A.cif (deflated 75%)
#   adding: structures/3J9K-B.cif (deflated 77%)
#   adding: structures/5JH9-A.cif (deflated 74%)
#   adding: structures/4FTE-A.cif (deflated 78%)
#   adding: structures/6AHI-A.cif (deflated 74%)
#   adding: structures/2ROK-A.cif (deflated 79%)
#   adding: structures/4ISX-A.cif (deflated 73%)
#   adding: structures/1PS9-A.cif (deflated 76%)
#   adding: structures/1NFG-A.cif (deflated 75%)
#   adding: structures/6PY9-A.cif (deflated 74%)
#   adding: structures/3LWX-A.cif (deflated 74%)
#   adding: structures/5AN1-A.cif (deflated 76%)
#   adding: structures/1THT-A.cif (deflated 74%)
#   adding: structures/5HFN-A.cif (deflated 73%)
#   adding: structures/2ESL-A.cif (deflated 76%)
#   adding: structures/2DZJ-A.cif (deflated 77%)
#   adding: structures/3WVL-O.cif (deflated 73%)
#   adding: structures/3O0O-A.cif (deflated 73%)
#   adding: structures/6KOC-D.cif (deflated 73%)
#   adding: structures/4PZA-A.cif (deflated 73%)
#   adding: structures/4PWV-A.cif (deflated 74%)
#   adding: structures/6KA1-A.cif (deflated 74%)
#   adding: structures/3PM8-A.cif (deflated 75%)
#   adding: structures/6KAF-a.cif (deflated 80%)
#   adding: structures/4XZW-A.cif (deflated 76%)
#   adding: structures/3NH5-A.cif (deflated 74%)
#   adding: structures/2C60-A.cif (deflated 74%)
#   adding: structures/4LDO-A.cif (deflated 72%)
#   adding: structures/4P82-A.cif (deflated 75%)
#   adding: structures/4OFZ-A.cif (deflated 74%)
#   adding: structures/4PMU-A.cif (deflated 74%)
#   adding: structures/1K1D-A.cif (deflated 75%)
#   adding: structures/4W9Z-A.cif (deflated 74%)
#   adding: structures/1ZVT-A.cif (deflated 75%)
#   adding: structures/6UQT-A.cif (deflated 75%)
#   adding: structures/3L4G-A.cif (deflated 75%)
#   adding: structures/5U8E-A.cif (deflated 74%)
#   adding: structures/1URH-A.cif (deflated 75%)
#   adding: structures/6FNU-A.cif (deflated 74%)
#   adding: structures/2BIH-A.cif (deflated 75%)
#   adding: structures/1VIX-A.cif (deflated 75%)
#   adding: structures/4KRT-A.cif (deflated 74%)
#   adding: structures/6CJB-A.cif (deflated 74%)
#   adding: structures/3NG0-A.cif (deflated 75%)
#   adding: structures/2P3S-A.cif (deflated 74%)
#   adding: structures/1PN2-A.cif (deflated 76%)
#   adding: structures/2VLA-A.cif (deflated 75%)
#   adding: structures/3V9H-A.cif (deflated 73%)
#   adding: structures/2Z11-A.cif (deflated 74%)
#   adding: structures/2XAA-A.cif (deflated 76%)
#   adding: structures/4TXV-B.cif (deflated 75%)
#   adding: structures/1QLM-A.cif (deflated 75%)
#   adding: structures/5AG8-A.cif (deflated 74%)
#   adding: structures/3A24-A.cif (deflated 75%)
#   adding: structures/2XE4-A.cif (deflated 74%)
#   adding: structures/3J2J-C.cif (deflated 76%)
#   adding: structures/1DBF-A.cif (deflated 73%)
#   adding: structures/3I9V-3.cif (deflated 76%)
#   adding: structures/5BS3-B.cif (deflated 76%)
#   adding: structures/4GZS-A.cif (deflated 76%)
#   adding: structures/2M85-A.cif (deflated 78%)
#   adding: structures/3D0F-A.cif (deflated 75%)
#   adding: structures/2BDW-A.cif (deflated 75%)
#   adding: structures/2PQI-A.cif (deflated 74%)
#   adding: structures/5LBK-A.cif (deflated 74%)
#   adding: structures/6K7W-A.cif (deflated 75%)
#   adding: structures/4B1C-A.cif (deflated 75%)
#   adding: structures/2A8L-A.cif (deflated 75%)
#   adding: structures/6JL8-A.cif (deflated 75%)
#   adding: structures/6AX3-A.cif (deflated 75%)
#   adding: structures/1NH8-A.cif (deflated 75%)
#   adding: structures/3MGX-A.cif (deflated 76%)
#   adding: structures/3IEI-A.cif (deflated 77%)
#   adding: structures/3HHD-A.cif (deflated 75%)
#   adding: structures/4Z03-A.cif (deflated 75%)
#   adding: structures/3PUC-A.cif (deflated 74%)
#   adding: structures/2CSM-A.cif (deflated 73%)
#   adding: structures/6NCW-A.cif (deflated 76%)
#   adding: structures/5J70-A.cif (deflated 74%)
#   adding: structures/3RAY-A.cif (deflated 73%)
#   adding: structures/3KVE-A.cif (deflated 75%)
#   adding: structures/2VUP-A.cif (deflated 74%)
#   adding: structures/1V9L-A.cif (deflated 75%)
#   adding: structures/1E6B-A.cif (deflated 73%)
#   adding: structures/1JCM-P.cif (deflated 75%)
#   adding: structures/3FGT-A.cif (deflated 75%)
#   adding: structures/4U9V-B.cif (deflated 73%)
#   adding: structures/2DU4-A.cif (deflated 75%)
#   adding: structures/6ACQ-A.cif (deflated 75%)
#   adding: structures/4QPN-A.cif (deflated 74%)
#   adding: structures/1I5E-A.cif (deflated 75%)
#   adding: structures/2CLY-A.cif (deflated 74%)
#   adding: structures/1F05-A.cif (deflated 75%)
#   adding: structures/5LOU-A.cif (deflated 75%)
#   adding: structures/5ZX8-A.cif (deflated 74%)
#   adding: structures/3BFK-A.cif (deflated 76%)
#   adding: structures/6IDK-D.cif (deflated 77%)
#   adding: structures/1G01-A.cif (deflated 75%)
#   adding: structures/2CPW-A.cif (deflated 77%)
#   adding: structures/6FAF-A.cif (deflated 75%)
#   adding: structures/1Z7S-3.cif (deflated 75%)
#   adding: structures/2R60-A.cif (deflated 74%)
#   adding: structures/4H27-A.cif (deflated 74%)
#   adding: structures/4KDI-C.cif (deflated 73%)
#   adding: structures/1OQA-A.cif (deflated 78%)
#   adding: structures/1L8N-A.cif (deflated 73%)
#   adding: structures/2YR0-A.cif (deflated 75%)
#   adding: structures/6HZ7-A.cif (deflated 80%)
#   adding: structures/5WG6-A.cif (deflated 74%)
#   adding: structures/6GBK-A.cif (deflated 75%)
#   adding: structures/2RBC-A.cif (deflated 75%)
#   adding: structures/3ELU-A.cif (deflated 75%)
#   adding: structures/2XFG-A.cif (deflated 75%)
#   adding: structures/1JUV-A.cif (deflated 74%)
#   adding: structures/1UIY-A.cif (deflated 75%)
#   adding: structures/1I8A-A.cif (deflated 75%)
#   adding: structures/4F62-A.cif (deflated 72%)
#   adding: structures/4RZ4-A.cif (deflated 76%)
#   adding: structures/1D1T-A.cif (deflated 76%)
#   adding: structures/4TNB-A.cif (deflated 74%)
#   adding: structures/4GSO-A.cif (deflated 74%)
#   adding: structures/6B02-A.cif (deflated 74%)
#   adding: structures/2PA6-A.cif (deflated 75%)
#   adding: structures/2B6N-A.cif (deflated 75%)
#   adding: structures/5O32-D.cif (deflated 71%)
#   adding: structures/6P4E-A.cif (deflated 75%)
#   adding: structures/6IUM-B.cif (deflated 76%)
#   adding: structures/3DR6-A.cif (deflated 76%)
#   adding: structures/4LIQ-E.cif (deflated 73%)
#   adding: structures/2Z5C-C.cif (deflated 74%)
#   adding: structures/5L9W-A.cif (deflated 73%)
#   adding: structures/3EUC-A.cif (deflated 75%)
#   adding: structures/3GTS-A.cif (deflated 75%)
#   adding: structures/3UOG-A.cif (deflated 73%)
#   adding: structures/2K4P-A.cif (deflated 74%)
#   adding: structures/5DUD-A.cif (deflated 74%)
#   adding: structures/4U3F-I.cif (deflated 76%)
#   adding: structures/2AJH-A.cif (deflated 74%)
#   adding: structures/3FIX-A.cif (deflated 75%)
#   adding: structures/4X28-D.cif (deflated 76%)
#   adding: structures/3KUL-B.cif (deflated 76%)
#   adding: structures/5EE0-A.cif (deflated 73%)
#   adding: structures/4DUT-A.cif (deflated 73%)
#   adding: structures/3REA-B.cif (deflated 73%)
#   adding: structures/2F1W-A.cif (deflated 75%)
#   adding: structures/5TE0-A.cif (deflated 74%)
#   adding: structures/1FWP-A.cif (deflated 75%)
#   adding: structures/1DYO-A.cif (deflated 75%)
#   adding: structures/4NMK-A.cif (deflated 76%)
#   adding: structures/2I3A-A.cif (deflated 75%)
#   adding: structures/3A22-A.cif (deflated 75%)
#   adding: structures/5VFT-S.cif (deflated 75%)
#   adding: structures/2HW1-A.cif (deflated 76%)
#   adding: structures/1UMP-A.cif (deflated 74%)
#   adding: structures/4I5S-A.cif (deflated 71%)
#   adding: structures/2YU2-A.cif (deflated 74%)
#   adding: structures/3FBT-A.cif (deflated 75%)
#   adding: structures/3ORR-A.cif (deflated 76%)
#   adding: structures/5YCF-B.cif (deflated 73%)
#   adding: structures/6J90-A.cif (deflated 76%)
#   adding: structures/6QGQ-B.cif (deflated 75%)
#   adding: structures/5J46-A.cif (deflated 73%)
#   adding: structures/3PL2-A.cif (deflated 73%)
#   adding: structures/3REM-A.cif (deflated 75%)
#   adding: structures/4V4C-B.cif (deflated 77%)
#   adding: structures/3L8H-A.cif (deflated 76%)
#   adding: structures/1QS2-A.cif (deflated 74%)
#   adding: structures/2OHY-A.cif (deflated 75%)
#   adding: structures/3LMG-A.cif (deflated 76%)
#   adding: structures/1K4M-A.cif (deflated 75%)
#   adding: structures/6EG3-A.cif (deflated 75%)
#   adding: structures/2F6U-A.cif (deflated 75%)
#   adding: structures/4QJ1-A.cif (deflated 73%)
#   adding: structures/3CJI-D.cif (deflated 75%)
#   adding: structures/4XWN-A.cif (deflated 73%)
#   adding: structures/3Q7I-A.cif (deflated 74%)
#   adding: structures/5E0Z-A.cif (deflated 74%)
#   adding: structures/5KNI-A.cif (deflated 73%)
#   adding: structures/6OHA-A.cif (deflated 73%)
#   adding: structures/2XDV-A.cif (deflated 73%)
#   adding: structures/1Z1W-A.cif (deflated 75%)
#   adding: structures/6DFZ-A.cif (deflated 73%)
#   adding: structures/1B0X-A.cif (deflated 75%)
#   adding: structures/3RYT-C.cif (deflated 73%)
#   adding: structures/3DKO-A.cif (deflated 73%)
#   adding: structures/4YRV-B.cif (deflated 75%)
#   adding: structures/3O59-X.cif (deflated 74%)
#   adding: structures/6NYO-A.cif (deflated 74%)
#   adding: structures/5LF0-A.cif (deflated 74%)
#   adding: structures/6MTK-A.cif (deflated 72%)
#   adding: structures/4IX2-A.cif (deflated 74%)
#   adding: structures/4XRN-A.cif (deflated 77%)
#   adding: structures/6MUV-B.cif (deflated 78%)
#   adding: structures/5UQL-A.cif (deflated 77%)
#   adding: structures/1O4V-A.cif (deflated 74%)
#   adding: structures/5U02-A.cif (deflated 72%)
#   adding: structures/1MAB-G.cif (deflated 76%)
#   adding: structures/1R6M-A.cif (deflated 74%)
#   adding: structures/1HYE-A.cif (deflated 75%)
#   adding: structures/3LQK-A.cif (deflated 74%)
#   adding: structures/5AWM-A.cif (deflated 75%)
#   adding: structures/6KJ5-A.cif (deflated 73%)
#   adding: structures/1T3I-A.cif (deflated 75%)
#   adding: structures/6EIC-C.cif (deflated 75%)
#   adding: structures/4KZP-A.cif (deflated 74%)
#   adding: structures/1VGJ-A.cif (deflated 74%)
#   adding: structures/5EIO-A.cif (deflated 75%)
#   adding: structures/3SOA-A.cif (deflated 71%)
#   adding: structures/4J94-A.cif (deflated 74%)
#   adding: structures/5JSR-A.cif (deflated 75%)
#   adding: structures/4FGM-A.cif (deflated 73%)
#   adding: structures/3A2K-A.cif (deflated 73%)
#   adding: structures/2XF8-A.cif (deflated 77%)
#   adding: structures/5JS6-A.cif (deflated 73%)
#   adding: structures/5N1Q-B.cif (deflated 74%)
#   adding: structures/6QC8-4L.cif (deflated 80%)
#   adding: structures/1TQY-A.cif (deflated 75%)
#   adding: structures/3TR4-A.cif (deflated 73%)
#   adding: structures/5HPT-A.cif (deflated 75%)
#   adding: structures/2BJI-A.cif (deflated 74%)
#   adding: structures/4WFT-C.cif (deflated 74%)
#   adding: structures/4R7Q-A.cif (deflated 72%)
#   adding: structures/3OE9-A.cif (deflated 72%)
#   adding: structures/1MA1-A.cif (deflated 76%)
#   adding: structures/4KJD-A.cif (deflated 75%)
#   adding: structures/6IEJ-A.cif (deflated 73%)
#   adding: structures/6IQY-A.cif (deflated 76%)
#   adding: structures/3UP5-A.cif (deflated 76%)
#   adding: structures/4NMI-A.cif (deflated 74%)
#   adding: structures/1NZI-A.cif (deflated 76%)
#   adding: structures/6UW3-B.cif (deflated 74%)
#   adding: structures/6VYE-A.cif (deflated 74%)
#   adding: structures/1U8V-A.cif (deflated 77%)
#   adding: structures/2FPQ-A.cif (deflated 75%)
#   adding: structures/2CW7-A.cif (deflated 74%)
#   adding: structures/5JK6-A.cif (deflated 74%)
#   adding: structures/3ZQS-A.cif (deflated 74%)
#   adding: structures/4JKM-A.cif (deflated 75%)
#   adding: structures/4F0K-B.cif (deflated 75%)
#   adding: structures/1O8B-A.cif (deflated 76%)
#   adding: structures/3ZRR-A.cif (deflated 76%)
#   adding: structures/5HK3-A.cif (deflated 76%)
#   adding: structures/2CUY-A.cif (deflated 75%)
#   adding: structures/5CV1-A.cif (deflated 72%)
#   adding: structures/2PGW-A.cif (deflated 76%)
#   adding: structures/4II2-C.cif (deflated 76%)
#   adding: structures/6M8V-A.cif (deflated 74%)
#   adding: structures/6T0V-B.cif (deflated 78%)
#   adding: structures/1YFL-A.cif (deflated 76%)
#   adding: structures/3JTM-A.cif (deflated 73%)
#   adding: structures/5MWL-A.cif (deflated 75%)
#   adding: structures/5OFW-B.cif (deflated 73%)
#   adding: structures/5TZM-A.cif (deflated 74%)
#   adding: structures/6O7G-B.cif (deflated 78%)
#   adding: structures/6P2A-A.cif (deflated 75%)
#   adding: structures/4NAE-B.cif (deflated 74%)
#   adding: structures/4CID-A.cif (deflated 74%)
#   adding: structures/3G87-A.cif (deflated 74%)
#   adding: structures/5XJ2-A.cif (deflated 76%)
#   adding: structures/1JV1-A.cif (deflated 76%)
#   adding: structures/1FRB-A.cif (deflated 75%)
#   adding: structures/6AYU-A.cif (deflated 75%)
#   adding: structures/2BFW-A.cif (deflated 75%)
#   adding: structures/3FQ6-A.cif (deflated 75%)
#   adding: structures/2FAW-A.cif (deflated 75%)
#   adding: structures/3PVJ-A.cif (deflated 75%)
#   adding: structures/2D9Z-A.cif (deflated 78%)
#   adding: structures/5EZW-A.cif (deflated 73%)
#   adding: structures/5FMG-C.cif (deflated 78%)
#   adding: structures/2F9Y-B.cif (deflated 75%)
#   adding: structures/1TQG-A.cif (deflated 75%)
#   adding: structures/2M4G-A.cif (deflated 77%)
#   adding: structures/6MEP-A.cif (deflated 76%)
#   adding: structures/1X87-A.cif (deflated 75%)
#   adding: structures/2Q5X-A.cif (deflated 75%)
#   adding: structures/1T6N-A.cif (deflated 74%)
#   adding: structures/3R2W-A.cif (deflated 73%)
#   adding: structures/4M7E-D.cif (deflated 75%)
#   adding: structures/4FLN-A.cif (deflated 73%)
#   adding: structures/3VMJ-A.cif (deflated 75%)
#   adding: structures/3T1E-A.cif (deflated 72%)
#   adding: structures/6H8K-5.cif (deflated 74%)
#   adding: structures/2X06-A.cif (deflated 74%)
#   adding: structures/5VPQ-A.cif (deflated 74%)
#   adding: structures/1F1A-A.cif (deflated 75%)
#   adding: structures/1YRK-A.cif (deflated 75%)
#   adding: structures/2KL2-A.cif (deflated 78%)
#   adding: structures/4ZH8-B.cif (deflated 74%)
#   adding: structures/1KDU-A.cif (deflated 76%)
#   adding: structures/3PC3-A.cif (deflated 74%)
#   adding: structures/6B9G-B.cif (deflated 73%)
#   adding: structures/3UF7-A.cif (deflated 73%)
#   adding: structures/4HA6-A.cif (deflated 75%)
#   adding: structures/1BCX-A.cif (deflated 75%)
#   adding: structures/4L1J-B.cif (deflated 73%)
#   adding: structures/2PTG-A.cif (deflated 74%)
#   adding: structures/4EJY-A.cif (deflated 76%)
#   adding: structures/2A1X-A.cif (deflated 74%)
#   adding: structures/6K5L-A.cif (deflated 75%)
#   adding: structures/2WNR-A.cif (deflated 75%)
#   adding: structures/2LM1-A.cif (deflated 75%)
#   adding: structures/4YTP-B.cif (deflated 75%)
#   adding: structures/6F5D-H.cif (deflated 76%)
#   adding: structures/4MB8-A.cif (deflated 73%)
#   adding: structures/2ZIG-A.cif (deflated 74%)
#   adding: structures/4RM7-A.cif (deflated 72%)
#   adding: structures/3J09-A.cif (deflated 77%)
#   adding: structures/6T3E-A.cif (deflated 70%)
#   adding: structures/3UPP-A.cif (deflated 73%)
#   adding: structures/5KSO-A.cif (deflated 76%)
#   adding: structures/6UE0-AAA.cif (deflated 76%)
#   adding: structures/4O9K-A.cif (deflated 74%)
#   adding: structures/4K6M-A.cif (deflated 76%)
#   adding: structures/1BXB-A.cif (deflated 75%)
#   adding: structures/2EFJ-A.cif (deflated 75%)
#   adding: structures/6FRV-A.cif (deflated 74%)
#   adding: structures/4LG7-A.cif (deflated 74%)
#   adding: structures/5JWO-A.cif (deflated 76%)
#   adding: structures/3WFS-C.cif (deflated 73%)
#   adding: structures/1ZCH-A.cif (deflated 76%)
#   adding: structures/4TXN-A.cif (deflated 74%)
#   adding: structures/5HCK-A.cif (deflated 75%)
#   adding: structures/4RMF-A.cif (deflated 73%)
#   adding: structures/5WLY-A.cif (deflated 76%)
#   adding: structures/4UW8-A.cif (deflated 76%)
#   adding: structures/4IS3-A.cif (deflated 74%)
#   adding: structures/5A9Q-5.cif (deflated 79%)
#   adding: structures/1YOV-B.cif (deflated 74%)
#   adding: structures/3T4P-A.cif (deflated 76%)
#   adding: structures/3M2P-A.cif (deflated 77%)
#   adding: structures/6BO7-A.cif (deflated 73%)
#   adding: structures/3TRI-A.cif (deflated 75%)
#   adding: structures/4NZZ-A.cif (deflated 74%)
#   adding: structures/4U1T-A.cif (deflated 75%)
#   adding: structures/5GJN-A.cif (deflated 75%)
#   adding: structures/1TJ7-A.cif (deflated 75%)
#   adding: structures/4V3F-A.cif (deflated 73%)
#   adding: structures/3B9J-B.cif (deflated 76%)
#   adding: structures/3G4D-A.cif (deflated 75%)
#   adding: structures/2K8D-A.cif (deflated 78%)
#   adding: structures/2O3B-A.cif (deflated 75%)
#   adding: structures/6CX1-C.cif (deflated 76%)
#   adding: structures/1S89-A.cif (deflated 74%)
#   adding: structures/3P3F-A.cif (deflated 73%)
#   adding: structures/3MK7-A.cif (deflated 73%)
#   adding: structures/3N0Y-A.cif (deflated 76%)
#   adding: structures/4V1O-R.cif (deflated 77%)
#   adding: structures/4GHK-A.cif (deflated 73%)
#   adding: structures/6IJN-A.cif (deflated 75%)
#   adding: structures/5IDI-A.cif (deflated 74%)
#   adding: structures/2VEP-A.cif (deflated 75%)
#   adding: structures/3MBW-A.cif (deflated 72%)
#   adding: structures/1PXV-C.cif (deflated 75%)
#   adding: structures/1VQU-A.cif (deflated 75%)
#   adding: structures/5N9Z-A.cif (deflated 76%)
#   adding: structures/6F5F-A.cif (deflated 75%)
#   adding: structures/3CTR-A.cif (deflated 75%)
#   adding: structures/3VO1-A.cif (deflated 75%)
#   adding: structures/1XFI-A.cif (deflated 75%)
#   adding: structures/2EKO-A.cif (deflated 77%)
#   adding: structures/2X6F-A.cif (deflated 75%)
#   adding: structures/1CJL-A.cif (deflated 75%)
#   adding: structures/3HH1-A.cif (deflated 75%)
#   adding: structures/4MJ2-A.cif (deflated 74%)
#   adding: structures/3T7V-A.cif (deflated 74%)
#   adding: structures/3ZCD-A.cif (deflated 73%)
#   adding: structures/2CFE-A.cif (deflated 73%)
#   adding: structures/5JE8-A.cif (deflated 73%)
#   adding: structures/1U3O-A.cif (deflated 77%)
#   adding: structures/3N6W-A.cif (deflated 74%)
#   adding: structures/5I9E-H.cif (deflated 73%)
#   adding: structures/1VBE-2.cif (deflated 74%)
#   adding: structures/4I1U-A.cif (deflated 73%)
#   adding: structures/3ZVQ-A.cif (deflated 75%)
#   adding: structures/1MVP-A.cif (deflated 74%)
#   adding: structures/4NWI-A.cif (deflated 74%)
#   adding: structures/6T21-A.cif (deflated 74%)
#   adding: structures/4DJH-A.cif (deflated 72%)
#   adding: structures/1FOA-A.cif (deflated 76%)
#   adding: structures/1EGZ-A.cif (deflated 75%)
#   adding: structures/1YSR-A.cif (deflated 75%)
#   adding: structures/3O4O-B.cif (deflated 72%)
#   adding: structures/5I4H-A.cif (deflated 76%)
#   adding: structures/2YY2-A.cif (deflated 75%)
#   adding: structures/2ENY-A.cif (deflated 78%)
#   adding: structures/4S3P-A.cif (deflated 73%)
#   adding: structures/2YV7-A.cif (deflated 74%)
#   adding: structures/3SFX-B.cif (deflated 74%)
#   adding: structures/3K7Y-A.cif (deflated 72%)
#   adding: structures/3AC0-A.cif (deflated 76%)
#   adding: structures/1YJS-A.cif (deflated 75%)
#   adding: structures/1YZY-A.cif (deflated 74%)
#   adding: structures/4IHG-A.cif (deflated 75%)
#   adding: structures/3OH0-A.cif (deflated 73%)
#   adding: structures/2H2W-A.cif (deflated 74%)
#   adding: structures/6DD2-A.cif (deflated 74%)
#   adding: structures/5UY8-A.cif (deflated 75%)
#   adding: structures/6KMX-aA.cif (deflated 80%)
#   adding: structures/1QGC-1.cif (deflated 76%)
#   adding: structures/5FAI-A.cif (deflated 75%)
#   adding: structures/3RM5-A.cif (deflated 73%)
#   adding: structures/3GCD-A.cif (deflated 74%)
#   adding: structures/3A4O-X.cif (deflated 74%)
#   adding: structures/2ZNJ-A.cif (deflated 75%)
#   adding: structures/6AMW-A.cif (deflated 75%)
#   adding: structures/1USO-A.cif (deflated 75%)
#   adding: structures/5ESW-A.cif (deflated 75%)
#   adding: structures/6QXZ-A.cif (deflated 78%)
#   adding: structures/3T2N-A.cif (deflated 73%)
#   adding: structures/2RQA-A.cif (deflated 75%)
#   adding: structures/3OZG-A.cif (deflated 76%)
#   adding: structures/3GD5-A.cif (deflated 75%)
#   adding: structures/4FE3-A.cif (deflated 76%)
#   adding: structures/4PPV-A.cif (deflated 72%)
#   adding: structures/2EL7-A.cif (deflated 75%)
#   adding: structures/6J7U-A.cif (deflated 74%)
#   adding: structures/6CBS-A.cif (deflated 74%)
#   adding: structures/3AD9-B.cif (deflated 76%)
#   adding: structures/2PR1-A.cif (deflated 75%)
#   adding: structures/1BUL-A.cif (deflated 74%)
#   adding: structures/6R3E-A.cif (deflated 75%)
#   adding: structures/1OTJ-A.cif (deflated 75%)
#   adding: structures/2EJA-A.cif (deflated 75%)
#   adding: structures/3ZWF-A.cif (deflated 74%)
#   adding: structures/6K0A-E.cif (deflated 79%)
#   adding: structures/1QZU-A.cif (deflated 77%)
#   adding: structures/2Z8S-A.cif (deflated 76%)
#   adding: structures/5H9M-A.cif (deflated 75%)
#   adding: structures/1WV2-A.cif (deflated 74%)
#   adding: structures/4DDG-A.cif (deflated 72%)
#   adding: structures/1V0Y-A.cif (deflated 75%)
#   adding: structures/6DNZ-A.cif (deflated 75%)
#   adding: structures/1R5J-A.cif (deflated 75%)
#   adding: structures/1QVW-A.cif (deflated 75%)
#   adding: structures/3LVM-A.cif (deflated 75%)
#   adding: structures/3C3K-A.cif (deflated 75%)
#   adding: structures/5ZNI-A.cif (deflated 74%)
#   adding: structures/2CFC-A.cif (deflated 76%)
#   adding: structures/6U7L-A.cif (deflated 73%)
#   adding: structures/3MH6-A.cif (deflated 75%)
#   adding: structures/2VYN-D.cif (deflated 75%)
#   adding: structures/4ABO-A.cif (deflated 76%)
#   adding: structures/5YKB-A.cif (deflated 76%)
#   adding: structures/2AC1-A.cif (deflated 75%)
#   adding: structures/5UY7-A.cif (deflated 73%)
#   adding: structures/6DBY-A.cif (deflated 75%)
#   adding: structures/4YH7-A.cif (deflated 74%)
#   adding: structures/5A04-A.cif (deflated 77%)
#   adding: structures/2OL1-A.cif (deflated 76%)
#   adding: structures/3HJR-A.cif (deflated 75%)
#   adding: structures/1VJV-A.cif (deflated 74%)
#   adding: structures/6A5C-A.cif (deflated 74%)
#   adding: structures/6RK4-A.cif (deflated 73%)
#   adding: structures/4G3P-A.cif (deflated 76%)
#   adding: structures/1XIQ-A.cif (deflated 74%)
#   adding: structures/6GVW-B.cif (deflated 73%)
#   adding: structures/6BAP-A.cif (deflated 75%)
#   adding: structures/3EFA-A.cif (deflated 73%)
#   adding: structures/4Y8P-I.cif (deflated 74%)
#   adding: structures/5MIY-A.cif (deflated 73%)
#   adding: structures/3WYD-A.cif (deflated 75%)
#   adding: structures/2CMW-A.cif (deflated 75%)
#   adding: structures/3IAC-A.cif (deflated 76%)
#   adding: structures/3PSN-A.cif (deflated 75%)
#   adding: structures/2W1K-A.cif (deflated 75%)
#   adding: structures/1CP2-A.cif (deflated 75%)
#   adding: structures/1GN0-A.cif (deflated 75%)
#   adding: structures/3E45-A.cif (deflated 76%)
#   adding: structures/3VK2-A.cif (deflated 76%)
#   adding: structures/2V0L-A.cif (deflated 75%)
#   adding: structures/5L9W-b.cif (deflated 73%)
#   adding: structures/1X5D-A.cif (deflated 78%)
#   adding: structures/3RFU-A.cif (deflated 73%)
#   adding: structures/1JNR-B.cif (deflated 76%)
#   adding: structures/3GBO-A.cif (deflated 75%)
#   adding: structures/4EFA-E.cif (deflated 72%)
#   adding: structures/3EQ1-A.cif (deflated 77%)
#   adding: structures/4A7P-A.cif (deflated 72%)
#   adding: structures/5N6Y-C.cif (deflated 74%)
#   adding: structures/6MVJ-A.cif (deflated 75%)
#   adding: structures/6LOI-A.cif (deflated 75%)
#   adding: structures/4UX7-A.cif (deflated 75%)
#   adding: structures/5HRB-A.cif (deflated 76%)
#   adding: structures/3HO9-A.cif (deflated 74%)
#   adding: structures/6EHA-A.cif (deflated 75%)
#   adding: structures/3KD8-A.cif (deflated 75%)
#   adding: structures/3PDX-A.cif (deflated 75%)
#   adding: structures/2WHL-A.cif (deflated 74%)
#   adding: structures/3HAY-A.cif (deflated 76%)
#   adding: structures/4JDY-A.cif (deflated 75%)
#   adding: structures/2LV3-A.cif (deflated 75%)
#   adding: structures/1G0D-A.cif (deflated 74%)
#   adding: structures/2HUN-A.cif (deflated 75%)
#   adding: structures/1NF4-A.cif (deflated 77%)
#   adding: structures/3U88-M.cif (deflated 75%)
#   adding: structures/4QOT-A.cif (deflated 75%)
#   adding: structures/2YVU-A.cif (deflated 74%)
#   adding: structures/6OX6-A.cif (deflated 72%)
#   adding: structures/3B1C-A.cif (deflated 76%)
#   adding: structures/5SVC-A.cif (deflated 73%)
#   adding: structures/1MUF-A.cif (deflated 74%)
#   adding: structures/3APQ-A.cif (deflated 73%)
#   adding: structures/4E4T-A.cif (deflated 74%)
#   adding: structures/6NUD-J.cif (deflated 78%)
#   adding: structures/3NOK-A.cif (deflated 75%)
#   adding: structures/1Z7S-4.cif (deflated 75%)
#   adding: structures/3OHP-A.cif (deflated 73%)
#   adding: structures/9LDB-A.cif (deflated 75%)
#   adding: structures/3C90-X.cif (deflated 75%)
#   adding: structures/5GY3-A.cif (deflated 74%)
#   adding: structures/5ITS-A.cif (deflated 75%)
#   adding: structures/2FEW-B.cif (deflated 76%)
#   adding: structures/2DEF-A.cif (deflated 78%)
#   adding: structures/2ADD-A.cif (deflated 75%)
#   adding: structures/1PV1-A.cif (deflated 74%)
#   adding: structures/3T14-A.cif (deflated 73%)
#   adding: structures/6FZ3-A.cif (deflated 74%)
#   adding: structures/2YJ4-A.cif (deflated 75%)
#   adding: structures/2V0N-A.cif (deflated 77%)
#   adding: structures/1WWC-A.cif (deflated 75%)
#   adding: structures/2QFY-A.cif (deflated 75%)
#   adding: structures/6I3S-A.cif (deflated 75%)
#   adding: structures/3DF0-A.cif (deflated 75%)
#   adding: structures/6DBN-A.cif (deflated 75%)
#   adding: structures/5JFI-A.cif (deflated 72%)
#   adding: structures/2FYR-A.cif (deflated 75%)
#   adding: structures/6R48-A.cif (deflated 74%)
#   adding: structures/3RSH-A.cif (deflated 73%)
#   adding: structures/4YB6-A.cif (deflated 76%)
#   adding: structures/6SLL-B.cif (deflated 74%)
#   adding: structures/4PFQ-A.cif (deflated 74%)
#   adding: structures/1V72-A.cif (deflated 75%)
#   adding: structures/1UAI-A.cif (deflated 75%)
#   adding: structures/4AA9-A.cif (deflated 75%)
#   adding: structures/2C2N-A.cif (deflated 75%)
#   adding: structures/1XDJ-A.cif (deflated 75%)
#   adding: structures/1FNO-A.cif (deflated 77%)
#   adding: structures/6HXF-B.cif (deflated 74%)
#   adding: structures/6C23-K.cif (deflated 75%)
#   adding: structures/2FC0-A.cif (deflated 76%)
#   adding: structures/1Q3S-A.cif (deflated 76%)
#   adding: structures/5UXI-A.cif (deflated 75%)
#   adding: structures/4QWP-A.cif (deflated 74%)
#   adding: structures/4LD7-A.cif (deflated 74%)
#   adding: structures/1RP0-A.cif (deflated 76%)
#   adding: structures/3PRA-A.cif (deflated 73%)
#   adding: structures/2GFQ-A.cif (deflated 76%)
#   adding: structures/3NWJ-A.cif (deflated 74%)
#   adding: structures/4AZ1-A.cif (deflated 73%)
#   adding: structures/5EUJ-A.cif (deflated 77%)
#   adding: structures/1S70-A.cif (deflated 74%)
#   adding: structures/4HTJ-A.cif (deflated 72%)
#   adding: structures/5OLW-A.cif (deflated 73%)
#   adding: structures/3L60-A.cif (deflated 74%)
#   adding: structures/6JP9-A.cif (deflated 76%)
#   adding: structures/2I6S-A.cif (deflated 74%)
#   adding: structures/3RFW-A.cif (deflated 74%)
#   adding: structures/6D8Z-A.cif (deflated 72%)
#   adding: structures/2KOI-A.cif (deflated 78%)
#   adding: structures/4JKL-A.cif (deflated 75%)
#   adding: structures/4GUD-A.cif (deflated 73%)
#   adding: structures/3TQH-A.cif (deflated 73%)
#   adding: structures/1P9P-A.cif (deflated 75%)
#   adding: structures/6Q63-A.cif (deflated 74%)
#   adding: structures/1YZ4-A.cif (deflated 75%)
#   adding: structures/1LVB-A.cif (deflated 75%)
#   adding: structures/3W6N-A.cif (deflated 76%)
#   adding: structures/1OII-A.cif (deflated 76%)
#   adding: structures/3JQJ-A.cif (deflated 75%)
#   adding: structures/6B2Q-A.cif (deflated 73%)
#   adding: structures/3PE8-A.cif (deflated 73%)
#   adding: structures/6C01-A.cif (deflated 75%)
#   adding: structures/2WBK-A.cif (deflated 76%)
#   adding: structures/3WV8-A.cif (deflated 74%)
#   adding: structures/2FQO-A.cif (deflated 75%)
#   adding: structures/1MC0-A.cif (deflated 75%)
#   adding: structures/2YUB-A.cif (deflated 78%)
#   adding: structures/1CHM-A.cif (deflated 76%)
#   adding: structures/2EQ6-A.cif (deflated 76%)
#   adding: structures/6DU7-A.cif (deflated 76%)
#   adding: structures/2L30-A.cif (deflated 78%)
#   adding: structures/1KUK-A.cif (deflated 76%)
#   adding: structures/2ABK-A.cif (deflated 74%)
#   adding: structures/6L7P-I.cif (deflated 78%)
#   adding: structures/2KNB-A.cif (deflated 76%)
#   adding: structures/4E1L-A.cif (deflated 73%)
#   adding: structures/6LHN-A.cif (deflated 76%)
#   adding: structures/1ZRM-A.cif (deflated 74%)
#   adding: structures/1CPM-A.cif (deflated 75%)
#   adding: structures/3A7Q-A.cif (deflated 75%)
#   adding: structures/1W4Y-A.cif (deflated 76%)
#   adding: structures/1DTD-A.cif (deflated 74%)
#   adding: structures/2GJX-A.cif (deflated 76%)
#   adding: structures/6TX3-B.cif (deflated 74%)
#   adding: structures/4GT8-A.cif (deflated 75%)
#   adding: structures/2BA1-H.cif (deflated 75%)
#   adding: structures/5D9K-A.cif (deflated 73%)
#   adding: structures/6KR3-A.cif (deflated 76%)
#   adding: structures/3LG3-A.cif (deflated 74%)
#   adding: structures/2VK6-A.cif (deflated 75%)
#   adding: structures/3ZV3-A.cif (deflated 77%)
#   adding: structures/3IXO-A.cif (deflated 74%)
#   adding: structures/4I6B-A.cif (deflated 74%)
#   adding: structures/4GB3-3.cif (deflated 75%)
#   adding: structures/4D81-A.cif (deflated 75%)
#   adding: structures/5JP0-A.cif (deflated 74%)
#   adding: structures/2EWN-A.cif (deflated 75%)
#   adding: structures/5KST-A.cif (deflated 73%)
#   adding: structures/2Y69-E.cif (deflated 76%)
#   adding: structures/5GY6-A.cif (deflated 74%)
#   adding: structures/1UW0-A.cif (deflated 78%)
#   adding: structures/3TI2-A.cif (deflated 74%)
#   adding: structures/2MUU-A.cif (deflated 78%)
#   adding: structures/3HY9-A.cif (deflated 76%)
#   adding: structures/6GXC-A.cif (deflated 75%)
#   adding: structures/6MRN-A.cif (deflated 74%)
#   adding: structures/4HRM-C.cif (deflated 75%)
#   adding: structures/2V6J-A.cif (deflated 75%)
#   adding: structures/3S69-A.cif (deflated 75%)
#   adding: structures/2KXE-A.cif (deflated 77%)
#   adding: structures/4S1T-A.cif (deflated 75%)
#   adding: structures/3IHO-A.cif (deflated 74%)
#   adding: structures/1E2T-A.cif (deflated 75%)
#   adding: structures/3TLF-A.cif (deflated 74%)
#   adding: structures/2GRA-A.cif (deflated 75%)
#   adding: structures/1RF6-A.cif (deflated 75%)
#   adding: structures/5Z2X-A.cif (deflated 74%)
#   adding: structures/6NZD-G.cif (deflated 78%)
#   adding: structures/1R9W-A.cif (deflated 74%)
#   adding: structures/2WNE-A.cif (deflated 74%)
#   adding: structures/2CWH-A.cif (deflated 75%)
#   adding: structures/5YSK-A.cif (deflated 76%)
#   adding: structures/3QPI-A.cif (deflated 73%)
#   adding: structures/2DPP-B.cif (deflated 74%)
#   adding: structures/3OQO-S.cif (deflated 75%)
#   adding: structures/5FEY-A.cif (deflated 72%)
#   adding: structures/5MLG-A.cif (deflated 74%)
#   adding: structures/1HG8-A.cif (deflated 75%)
#   adding: structures/2YPD-A.cif (deflated 74%)
#   adding: structures/3QBD-A.cif (deflated 74%)
#   adding: structures/3KO8-A.cif (deflated 74%)
#   adding: structures/3JWE-A.cif (deflated 74%)
#   adding: structures/5M85-A.cif (deflated 75%)
#   adding: structures/1G5T-A.cif (deflated 76%)
#   adding: structures/3WZ0-C.cif (deflated 75%)
#   adding: structures/2DUL-A.cif (deflated 74%)
#   adding: structures/5W2O-A.cif (deflated 74%)
#   adding: structures/2YUR-A.cif (deflated 78%)
#   adding: structures/5O3Z-A.cif (deflated 76%)
#   adding: structures/1AL8-A.cif (deflated 75%)
#   adding: structures/3R0O-A.cif (deflated 74%)
#   adding: structures/1T24-A.cif (deflated 74%)
#   adding: structures/4XCS-A.cif (deflated 76%)
#   adding: structures/4IQM-A.cif (deflated 74%)
#   adding: structures/5UTV-A.cif (deflated 77%)
#   adding: structures/5VPU-A.cif (deflated 74%)
#   adding: structures/2A1A-B.cif (deflated 74%)
#   adding: structures/2FOI-A.cif (deflated 75%)
#   adding: structures/4KXH-A.cif (deflated 75%)
#   adding: structures/5MIM-A.cif (deflated 75%)
#   adding: structures/6RJ8-A.cif (deflated 73%)
#   adding: structures/1Z1F-A.cif (deflated 74%)
#   adding: structures/5W1U-A.cif (deflated 76%)
#   adding: structures/3HVA-A.cif (deflated 74%)
#   adding: structures/6FGK-A.cif (deflated 74%)
#   adding: structures/2O0B-A.cif (deflated 74%)
#   adding: structures/6DZ3-A.cif (deflated 75%)
#   adding: structures/2XVP-A.cif (deflated 74%)
#   adding: structures/5ABK-A.cif (deflated 74%)
#   adding: structures/4USR-A.cif (deflated 76%)
#   adding: structures/3J0C-B.cif (deflated 77%)
#   adding: structures/3L1R-A.cif (deflated 76%)
#   adding: structures/6CR0-A.cif (deflated 74%)
#   adding: structures/3GTY-X.cif (deflated 74%)
#   adding: structures/5ZQJ-A.cif (deflated 75%)
#   adding: structures/2GP4-A.cif (deflated 75%)
#   adding: structures/3RSZ-A.cif (deflated 75%)
#   adding: structures/1HV8-A.cif (deflated 77%)
#   adding: structures/4Z5S-A.cif (deflated 73%)
#   adding: structures/1AK1-A.cif (deflated 74%)
#   adding: structures/4AZ4-A.cif (deflated 73%)
#   adding: structures/3GPD-R.cif (deflated 77%)
#   adding: structures/6MGI-A.cif (deflated 75%)
#   adding: structures/6KU8-A.cif (deflated 75%)
#   adding: structures/4TTR-A.cif (deflated 74%)
#   adding: structures/3SBP-A.cif (deflated 75%)
#   adding: structures/5FII-A.cif (deflated 75%)
#   adding: structures/6CHJ-A.cif (deflated 75%)
#   adding: structures/1QSA-A.cif (deflated 75%)
#   adding: structures/4COK-A.cif (deflated 76%)
#   adding: structures/2EO0-A.cif (deflated 74%)
#   adding: structures/1BCP-C.cif (deflated 76%)
#   adding: structures/1TPG-A.cif (deflated 76%)
#   adding: structures/6T5S-A.cif (deflated 77%)
#   adding: structures/6NU3-p.cif (deflated 79%)
#   adding: structures/3DLX-A.cif (deflated 75%)
#   adding: structures/2YB4-A.cif (deflated 74%)
#   adding: structures/1Q5D-A.cif (deflated 74%)
#   adding: structures/2X4D-A.cif (deflated 75%)
#   adding: structures/3DZ1-A.cif (deflated 75%)
#   adding: structures/5JIF-A.cif (deflated 74%)
#   adding: structures/2PJR-A.cif (deflated 76%)
#   adding: structures/2ZK9-X.cif (deflated 74%)
#   adding: structures/6TKV-B.cif (deflated 74%)
#   adding: structures/5WM0-A.cif (deflated 75%)
#   adding: structures/1EB6-A.cif (deflated 74%)
#   adding: structures/5K22-A.cif (deflated 72%)
#   adding: structures/1XHX-A.cif (deflated 75%)
#   adding: structures/4WIM-A.cif (deflated 75%)
#   adding: structures/1NQD-A.cif (deflated 76%)
#   adding: structures/2EBA-A.cif (deflated 76%)
#   adding: structures/4RNU-A.cif (deflated 73%)
#   adding: structures/4P7I-C.cif (deflated 72%)
#   adding: structures/3G7I-A.cif (deflated 75%)
#   adding: structures/6G3X-A.cif (deflated 75%)
#   adding: structures/1GUL-A.cif (deflated 75%)
#   adding: structures/6FWH-A.cif (deflated 76%)
#   adding: structures/3RE3-A.cif (deflated 73%)
#   adding: structures/4WZ7-L.cif (deflated 75%)
#   adding: structures/3F5O-A.cif (deflated 76%)
#   adding: structures/5CAB-A.cif (deflated 72%)
#   adding: structures/3P8G-A.cif (deflated 74%)
#   adding: structures/1VKR-A.cif (deflated 75%)
#   adding: structures/6H18-A.cif (deflated 76%)
#   adding: structures/2C91-A.cif (deflated 76%)
#   adding: structures/6PZ2-A.cif (deflated 76%)
#   adding: structures/2JER-A.cif (deflated 75%)
#   adding: structures/2YEV-A.cif (deflated 73%)
#   adding: structures/6RFQ-I.cif (deflated 79%)
#   adding: structures/1JQP-A.cif (deflated 74%)
#   adding: structures/3CJR-A.cif (deflated 76%)
#   adding: structures/3HLK-A.cif (deflated 75%)
#   adding: structures/1CI8-A.cif (deflated 75%)
#   adding: structures/6ABX-A.cif (deflated 75%)
#   adding: structures/3M7F-B.cif (deflated 73%)
#   adding: structures/2ATX-A.cif (deflated 76%)
#   adding: structures/5VM9-A.cif (deflated 73%)
#   adding: structures/2ISS-A.cif (deflated 75%)
#   adding: structures/6D24-C.cif (deflated 73%)
#   adding: structures/2JA1-A.cif (deflated 76%)
#   adding: structures/1SQE-A.cif (deflated 74%)
#   adding: structures/1YRZ-A.cif (deflated 75%)
#   adding: structures/4S25-A.cif (deflated 76%)
#   adding: structures/2QYU-A.cif (deflated 72%)
#   adding: structures/6AHV-A.cif (deflated 72%)
#   adding: structures/2WZQ-A.cif (deflated 75%)
#   adding: structures/4JLX-A.cif (deflated 74%)
#   adding: structures/6LNU-A.cif (deflated 76%)
#   adding: structures/3TJQ-A.cif (deflated 73%)
#   adding: structures/4KBM-A.cif (deflated 73%)
#   adding: structures/2INR-A.cif (deflated 74%)
#   adding: structures/6GFJ-A.cif (deflated 73%)
#   adding: structures/4B6G-A.cif (deflated 75%)
#   adding: structures/4DF3-A.cif (deflated 75%)
#   adding: structures/1JLV-A.cif (deflated 75%)
#   adding: structures/3N44-A.cif (deflated 73%)
#   adding: structures/3MC4-A.cif (deflated 74%)
#   adding: structures/1CJW-A.cif (deflated 74%)
#   adding: structures/3WTB-A.cif (deflated 74%)
#   adding: structures/6NDL-A.cif (deflated 72%)
#   adding: structures/3MPG-A.cif (deflated 75%)
#   adding: structures/1A8S-A.cif (deflated 74%)
#   adding: structures/5JWG-A.cif (deflated 73%)
#   adding: structures/3FKK-A.cif (deflated 74%)
#   adding: structures/6J5C-A.cif (deflated 73%)
#   adding: structures/5E2E-A.cif (deflated 73%)
#   adding: structures/3W95-A.cif (deflated 76%)
#   adding: structures/2Z2U-A.cif (deflated 74%)
#   adding: structures/1DCU-A.cif (deflated 75%)
#   adding: structures/4IIV-A.cif (deflated 75%)
#   adding: structures/6IDW-A.cif (deflated 75%)
#   adding: structures/3JB4-C.cif (deflated 74%)
#   adding: structures/2JC3-A.cif (deflated 76%)
#   adding: structures/2JU1-A.cif (deflated 77%)
#   adding: structures/5FUD-A.cif (deflated 75%)
#   adding: structures/1X5L-A.cif (deflated 78%)
#   adding: structures/5U9P-A.cif (deflated 74%)
#   adding: structures/4ZRN-A.cif (deflated 76%)
#   adding: structures/4R36-A.cif (deflated 75%)
#   adding: structures/4YYW-A.cif (deflated 74%)
#   adding: structures/1IRU-A.cif (deflated 76%)
#   adding: structures/2GL9-A.cif (deflated 74%)
#   adding: structures/3GDB-A.cif (deflated 75%)
#   adding: structures/1BQB-A.cif (deflated 75%)
#   adding: structures/3LN6-A.cif (deflated 72%)
#   adding: structures/2IXB-A.cif (deflated 74%)
#   adding: structures/4H3Y-A.cif (deflated 73%)
#   adding: structures/3W77-A.cif (deflated 74%)
#   adding: structures/3NJ3-A.cif (deflated 75%)
#   adding: structures/6FNN-A.cif (deflated 73%)
#   adding: structures/5B48-B.cif (deflated 76%)
#   adding: structures/5HC2-A.cif (deflated 76%)
#   adding: structures/6ERK-A.cif (deflated 73%)
#   adding: structures/3I83-A.cif (deflated 75%)
#   adding: structures/2B3J-A.cif (deflated 76%)
#   adding: structures/4TM8-A.cif (deflated 72%)
#   adding: structures/1GC4-A.cif (deflated 75%)
#   adding: structures/1R5T-A.cif (deflated 75%)
#   adding: structures/1D6Z-A.cif (deflated 76%)
#   adding: structures/5FW4-A.cif (deflated 74%)
#   adding: structures/3NB7-A.cif (deflated 73%)
#   adding: structures/5D6R-B.cif (deflated 73%)
#   adding: structures/5FO8-A.cif (deflated 73%)
#   adding: structures/6BA1-A.cif (deflated 74%)
#   adding: structures/3FII-A.cif (deflated 75%)
#   adding: structures/3Q1X-A.cif (deflated 75%)
#   adding: structures/5C0W-K.cif (deflated 74%)
#   adding: structures/1ITU-A.cif (deflated 75%)
#   adding: structures/1Y9K-A.cif (deflated 75%)
#   adding: structures/2IFC-A.cif (deflated 76%)
#   adding: structures/5DK1-A.cif (deflated 74%)
#   adding: structures/5QIP-A.cif (deflated 74%)
#   adding: structures/6MDY-A.cif (deflated 73%)
#   adding: structures/5L8H-A.cif (deflated 73%)
#   adding: structures/1X9J-A.cif (deflated 75%)
#   adding: structures/1KEV-A.cif (deflated 75%)
#   adding: structures/3L2P-A.cif (deflated 73%)
#   adding: structures/4PO6-A.cif (deflated 74%)
#   adding: structures/2G2N-A.cif (deflated 76%)
#   adding: structures/1R1A-2.cif (deflated 77%)
#   adding: structures/3FSR-A.cif (deflated 74%)
#   adding: structures/6A8I-A.cif (deflated 75%)
#   adding: structures/5B57-C.cif (deflated 73%)
#   adding: structures/6RA4-A.cif (deflated 75%)
#   adding: structures/2WDT-A.cif (deflated 75%)
#   adding: structures/2QHE-A.cif (deflated 74%)
#   adding: structures/2RI0-A.cif (deflated 75%)
#   adding: structures/3CH2-X.cif (deflated 75%)
#   adding: structures/2HSX-A.cif (deflated 77%)
#   adding: structures/4DZR-A.cif (deflated 72%)
#   adding: structures/2DE0-X.cif (deflated 74%)
#   adding: structures/5L9W-C.cif (deflated 73%)
#   adding: structures/3L5K-A.cif (deflated 75%)
#   adding: structures/1BCP-B.cif (deflated 76%)
#   adding: structures/2MBB-A.cif (deflated 78%)
#   adding: structures/2H31-A.cif (deflated 75%)
#   adding: structures/6MPT-A.cif (deflated 76%)
#   adding: structures/4PVC-A.cif (deflated 74%)
#   adding: structures/3AWI-A.cif (deflated 73%)
#   adding: structures/6GFW-M.cif (deflated 76%)
#   adding: structures/3PTY-A.cif (deflated 74%)
#   adding: structures/3SL2-A.cif (deflated 74%)
# ...
#   adding: cache/1V59-A.pt (deflated 83%)
#   adding: cache/2DLE-A.pt (deflated 78%)
#   adding: cache/3O0O-A.pt (deflated 83%)
#   adding: cache/4S17-A.pt (deflated 83%)
#   adding: cache/1E1H-A.pt (deflated 81%)
#   adding: cache/3OJ6-A.pt (deflated 78%)
#   adding: cache/4PDO-A.pt (deflated 81%)
#   adding: cache/3S6K-A.pt (deflated 83%)
#   adding: cache/1OFH-G.pt (deflated 79%)
#   adding: cache/2HUN-A.pt (deflated 81%)
#   adding: cache/1NZI-A.pt (deflated 78%)
#   adding: cache/1HUX-A.pt (deflated 81%)
#   adding: cache/2VLA-A.pt (deflated 81%)
#   adding: cache/3RE1-A.pt (deflated 81%)
#   adding: cache/1DTD-A.pt (deflated 81%)
#   adding: cache/1FB1-A.pt (deflated 79%)
#   adding: cache/2JBW-A.pt (deflated 82%)
#   adding: cache/5ICN-B.pt (deflated 82%)
#   adding: cache/2WBK-A.pt (deflated 84%)
#   adding: cache/5EE0-A.pt (deflated 82%)
#   adding: cache/6EIC-C.pt (deflated 81%)
#   adding: cache/1X5D-A.pt (deflated 79%)
#   adding: cache/2X8T-A.pt (deflated 82%)
#   adding: cache/2DQA-A.pt (deflated 77%)
#   adding: cache/2PBZ-A.pt (deflated 81%)
#   adding: cache/3V48-A.pt (deflated 81%)
#   adding: cache/3WFO-A.pt (deflated 83%)
#   adding: cache/2F7F-A.pt (deflated 83%)
#   adding: cache/3HH1-A.pt (deflated 76%)
#   adding: cache/1O58-A.pt (deflated 81%)
#   adding: cache/1NYE-A.pt (deflated 78%)
#   adding: cache/4HCX-A.pt (deflated 82%)
#   adding: cache/6E24-A.pt (deflated 81%)
#   adding: cache/3PC3-A.pt (deflated 83%)
#   adding: cache/4HDR-A.pt (deflated 81%)
#   adding: cache/5UQL-A.pt (deflated 83%)
#   adding: cache/1BDY-A.pt (deflated 76%)
#   adding: cache/6FLN-A.pt (deflated 83%)
#   adding: cache/2CX9-A.pt (deflated 82%)
#   adding: cache/2EFJ-A.pt (deflated 82%)
#   adding: cache/2E2H-H.pt (deflated 77%)
#   adding: cache/1VP5-A.pt (deflated 81%)
#   adding: cache/6XTY-4.pt (deflated 85%)
#   adding: cache/5KCK-A.pt (deflated 82%)
#   adding: cache/1PXV-C.pt (deflated 75%)
#   adding: cache/4REP-A.pt (deflated 83%)
#   adding: cache/3C8G-A.pt (deflated 79%)
#   adding: cache/2R5U-A.pt (deflated 79%)
#   adding: cache/4QJV-B.pt (deflated 74%)
#   adding: cache/4DLL-A.pt (deflated 81%)
#   adding: cache/6LNU-A.pt (deflated 83%)
#   adding: cache/4IJ1-A.pt (deflated 82%)
#   adding: cache/4DDG-A.pt (deflated 82%)
#   adding: cache/4J5W-C.pt (deflated 81%)
#   adding: cache/6BA1-A.pt (deflated 81%)
#   adding: cache/4TR8-A.pt (deflated 82%)
#   adding: cache/3IPJ-A.pt (deflated 74%)
#   adding: cache/4K33-A.pt (deflated 81%)
#   adding: cache/6BQZ-A.pt (deflated 83%)
#   adding: cache/3N2T-A.pt (deflated 82%)
#   adding: cache/3AHX-A.pt (deflated 82%)
#   adding: cache/4J94-A.pt (deflated 82%)
#   adding: cache/1H7T-A.pt (deflated 80%)
#   adding: cache/5J70-A.pt (deflated 81%)
#   adding: cache/1XRS-B.pt (deflated 81%)
#   adding: cache/5JTV-A.pt (deflated 83%)
#   adding: cache/1OGK-A.pt (deflated 81%)
#   adding: cache/6NK6-A.pt (deflated 82%)
#   adding: cache/5OHK-A.pt (deflated 81%)
#   adding: cache/1UW0-A.pt (deflated 79%)
#   adding: cache/6JNK-A.pt (deflated 81%)
#   adding: cache/4CNG-A.pt (deflated 81%)
#   adding: cache/2ASH-A.pt (deflated 82%)
#   adding: cache/5EYZ-A.pt (deflated 75%)
#   adding: cache/5L0Z-A.pt (deflated 81%)
#   adding: cache/4EXP-X.pt (deflated 81%)
#   adding: cache/1WXM-A.pt (deflated 79%)
#   adding: cache/1A88-A.pt (deflated 81%)
#   adding: cache/4PUF-A.pt (deflated 84%)
#   adding: cache/1JUV-A.pt (deflated 79%)
#   adding: cache/6XTX-2.pt (deflated 85%)
#   adding: cache/5VEU-A.pt (deflated 83%)
#   adding: cache/1IQ0-A.pt (deflated 83%)
#   adding: cache/5JY7-I.pt (deflated 82%)
#   adding: cache/2D5K-A.pt (deflated 78%)
#   adding: cache/6IHG-A.pt (deflated 79%)
#   adding: cache/2NBQ-A.pt (deflated 79%)
#   adding: cache/4I6W-A.pt (deflated 82%)
#   adding: cache/1PV1-A.pt (deflated 81%)
#   adding: cache/2XRX-A.pt (deflated 82%)
#   adding: cache/6KJD-B.pt (deflated 82%)
#   adding: cache/3K2Q-A.pt (deflated 82%)
#   adding: cache/2WDT-A.pt (deflated 80%)
#   adding: cache/2YB4-A.pt (deflated 81%)
#   adding: cache/3AEU-A.pt (deflated 82%)
#   adding: cache/4Q2B-A.pt (deflated 82%)
#   adding: cache/4BLN-A.pt (deflated 81%)
#   adding: cache/2XFG-A.pt (deflated 82%)
#   adding: cache/1HG8-A.pt (deflated 82%)
#   adding: cache/1G01-A.pt (deflated 82%)
#   adding: cache/4IRU-A.pt (deflated 81%)
#   adding: cache/1GZU-A.pt (deflated 81%)
#   adding: cache/3H3K-A.pt (deflated 83%)
#   adding: cache/3H9M-A.pt (deflated 82%)
#   adding: cache/2JG6-A.pt (deflated 79%)
#   adding: cache/3G5K-A.pt (deflated 79%)
#   adding: cache/3BSM-A.pt (deflated 82%)
#   adding: cache/3Q6D-A.pt (deflated 82%)
#   adding: cache/4JSB-A.pt (deflated 81%)
#   adding: cache/3HDN-A.pt (deflated 82%)
#   adding: cache/3L8U-A.pt (deflated 79%)
#   adding: cache/4LD7-A.pt (deflated 83%)
#   adding: cache/4XU2-A.pt (deflated 81%)
#   adding: cache/3H49-A.pt (deflated 81%)
#   adding: cache/1RWG-A.pt (deflated 83%)
#   adding: cache/3OQO-S.pt (deflated 74%)
#   adding: cache/1V72-A.pt (deflated 82%)
#   adding: cache/2WA2-A.pt (deflated 81%)
#   adding: cache/1LXY-A.pt (deflated 82%)
#   adding: cache/2OK3-A.pt (deflated 78%)
#   adding: cache/4IS3-A.pt (deflated 81%)
#   adding: cache/2GJX-A.pt (deflated 83%)
#   adding: cache/2MDR-A.pt (deflated 79%)
#   adding: cache/6U0M-3.pt (deflated 84%)
#   adding: cache/4WZ7-L.pt (deflated 74%)
#   adding: cache/2OU7-A.pt (deflated 82%)
#   adding: cache/6PAW-A.pt (deflated 81%)
#   adding: cache/3KDJ-B.pt (deflated 81%)
#   adding: cache/3RM5-A.pt (deflated 83%)
#   adding: cache/3P1I-A.pt (deflated 79%)
#   adding: cache/2HYI-C.pt (deflated 82%)
#   adding: cache/5FUD-A.pt (deflated 80%)
#   adding: cache/3TLF-A.pt (deflated 81%)
#   adding: cache/2GL9-A.pt (deflated 78%)
#   adding: cache/5VM9-A.pt (deflated 84%)
#   adding: cache/3TY7-A.pt (deflated 82%)
#   adding: cache/1BUN-A.pt (deflated 76%)
#   adding: cache/1O4V-A.pt (deflated 79%)
#   adding: cache/3PL3-A.pt (deflated 82%)
#   adding: cache/2PTG-A.pt (deflated 82%)
#   adding: cache/3FFY-A.pt (deflated 76%)
#   adding: cache/2JZA-A.pt (deflated 78%)
#   adding: cache/2FUG-7.pt (deflated 77%)
#   adding: cache/2FPQ-A.pt (deflated 82%)
#   adding: cache/1CHM-A.pt (deflated 82%)
#   adding: cache/3K8C-A.pt (deflated 79%)
#   adding: cache/4E6K-A.pt (deflated 78%)
#   adding: cache/4G8L-A.pt (deflated 82%)
#   adding: cache/3JUS-A.pt (deflated 83%)
#   adding: cache/4ISX-A.pt (deflated 79%)
#   adding: cache/5DZ7-A.pt (deflated 81%)
#   adding: cache/6OOI-A.pt (deflated 81%)
#   adding: cache/1YFL-A.pt (deflated 80%)
#   adding: cache/3EXI-A.pt (deflated 82%)
#   adding: cache/2BA1-H.pt (deflated 81%)
#   adding: cache/1R5T-A.pt (deflated 77%)
#   adding: cache/5HCI-A.pt (deflated 81%)
#   adding: cache/1BOL-A.pt (deflated 80%)
#   adding: cache/6RFQ-I.pt (deflated 80%)
#   adding: cache/2UVD-A.pt (deflated 80%)
#   adding: cache/1QU3-A.pt (deflated 84%)
#   adding: cache/3T1E-A.pt (deflated 83%)
#   adding: cache/3RFW-A.pt (deflated 81%)
#   adding: cache/6CN1-A.pt (deflated 82%)
#   adding: cache/1QLM-A.pt (deflated 81%)
#   adding: cache/4V0R-A.pt (deflated 84%)
#   adding: cache/5D9K-A.pt (deflated 82%)
#   adding: cache/4FAZ-A.pt (deflated 70%)
#   adding: cache/5I6E-A.pt (deflated 84%)
#   adding: cache/1C3C-A.pt (deflated 82%)
#   adding: cache/4GV6-A.pt (deflated 79%)
#   adding: cache/6D5C-A.pt (deflated 82%)
#   adding: cache/3WV8-A.pt (deflated 80%)
#   adding: cache/5N6I-A.pt (deflated 82%)
#   adding: cache/3UPP-A.pt (deflated 82%)
#   adding: cache/3IEI-A.pt (deflated 82%)
#   adding: cache/4JRH-A.pt (deflated 82%)
#   adding: cache/1W18-A.pt (deflated 82%)
#   adding: cache/3ELE-A.pt (deflated 82%)
#   adding: cache/2PBJ-A.pt (deflated 81%)
#   adding: cache/5B2C-A.pt (deflated 83%)
#   adding: cache/5L51-A.pt (deflated 81%)
#   adding: cache/5ESZ-C.pt (deflated 80%)
#   adding: cache/4B24-A.pt (deflated 80%)
#   adding: cache/5U02-A.pt (deflated 82%)
#   adding: cache/6SU2-A.pt (deflated 83%)
#   adding: cache/5YLN-A.pt (deflated 82%)
#   adding: cache/1NQD-A.pt (deflated 76%)
#   adding: cache/4EGF-A.pt (deflated 81%)
#   adding: cache/4DZ6-A.pt (deflated 79%)
#   adding: cache/3KUK-A.pt (deflated 81%)
#   adding: cache/5Z7R-A.pt (deflated 81%)
#   adding: cache/5MLG-A.pt (deflated 82%)
#   adding: cache/3IPL-A.pt (deflated 83%)
#   adding: cache/6B8S-A.pt (deflated 82%)
#   adding: cache/1XDJ-A.pt (deflated 84%)
#   adding: cache/2L30-A.pt (deflated 78%)
#   adding: cache/1KDU-A.pt (deflated 74%)
#   adding: cache/3AC0-A.pt (deflated 83%)
#   adding: cache/6OHA-A.pt (deflated 83%)
#   adding: cache/1CP2-A.pt (deflated 81%)
#   adding: cache/3ZC7-A.pt (deflated 81%)
#   adding: cache/6TVP-A.pt (deflated 82%)
#   adding: cache/5F3M-A.pt (deflated 76%)
#   adding: cache/6AG5-A.pt (deflated 78%)
#   adding: cache/1RQX-A.pt (deflated 81%)
#   adding: cache/2KIE-A.pt (deflated 79%)
#   adding: cache/3NJ3-A.pt (deflated 82%)
#   adding: cache/1V9N-A.pt (deflated 82%)
#   adding: cache/6MZB-A.pt (deflated 84%)
#   adding: cache/5ACA-1.pt (deflated 79%)
#   adding: cache/5L8W-A.pt (deflated 82%)
#   adding: cache/5K1Q-A.pt (deflated 82%)
#   adding: cache/5HA4-A.pt (deflated 81%)
#   adding: cache/2RUH-A.pt (deflated 79%)
#   adding: cache/6IDW-A.pt (deflated 81%)
#   adding: cache/3Q0I-A.pt (deflated 81%)
#   adding: cache/6D24-C.pt (deflated 83%)
#   adding: cache/3V9H-A.pt (deflated 83%)
#   adding: cache/1O5W-A.pt (deflated 83%)
#   adding: cache/4PO6-A.pt (deflated 83%)
#   adding: cache/5H5Q-A.pt (deflated 78%)
#   adding: cache/2X6F-A.pt (deflated 84%)
#   adding: cache/5MV0-A.pt (deflated 79%)
#   adding: cache/2BAA-A.pt (deflated 80%)
#   adding: cache/4L0J-A.pt (deflated 81%)
#   adding: cache/4A26-A.pt (deflated 81%)
#   adding: cache/1X87-A.pt (deflated 83%)
#   adding: cache/4R6L-A.pt (deflated 83%)
#   adding: cache/3IT7-A.pt (deflated 79%)
#   adding: cache/4IQM-A.pt (deflated 81%)
#   adding: cache/6C23-K.pt (deflated 86%)
#   adding: cache/5HKE-A.pt (deflated 81%)
#   adding: cache/5K8S-A.pt (deflated 78%)
#   adding: cache/1DNP-A.pt (deflated 83%)
#   adding: cache/6ABX-A.pt (deflated 82%)
#   adding: cache/3CEA-A.pt (deflated 82%)
#   adding: cache/4MB8-A.pt (deflated 81%)
#   adding: cache/5GY3-A.pt (deflated 81%)
#   adding: cache/4A7P-A.pt (deflated 82%)
#   adding: cache/5MY0-A.pt (deflated 83%)
#   adding: cache/1W2I-A.pt (deflated 74%)
#   adding: cache/6K0A-A.pt (deflated 77%)
#   adding: cache/4H4G-A.pt (deflated 78%)
#   adding: cache/11AS-A.pt (deflated 81%)
#   adding: cache/5KZM-B.pt (deflated 82%)
#   adding: cache/3MPG-A.pt (deflated 82%)
#   adding: cache/1GUL-A.pt (deflated 80%)
#   adding: cache/4V1Z-A.pt (deflated 82%)
#   adding: cache/2Z04-A.pt (deflated 82%)
#   adding: cache/2NZ2-A.pt (deflated 82%)
#   adding: cache/1H4S-A.pt (deflated 83%)
#   adding: cache/6FZ3-A.pt (deflated 82%)
#   adding: cache/1R0V-A.pt (deflated 81%)
#   adding: cache/4RLW-B.pt (deflated 78%)
#   adding: cache/3C2T-A.pt (deflated 77%)
#   adding: cache/2PJR-A.pt (deflated 83%)
#   adding: cache/4RMF-A.pt (deflated 83%)
#   adding: cache/1RF6-A.pt (deflated 82%)
#   adding: cache/4DBG-A.pt (deflated 74%)
#   adding: cache/5O3Z-A.pt (deflated 81%)
#   adding: cache/4P82-A.pt (deflated 79%)
#   adding: cache/2GEF-A.pt (deflated 80%)
#   adding: cache/3FAO-A.pt (deflated 80%)
#   adding: cache/1ZVT-A.pt (deflated 80%)
#   adding: cache/5UB9-A.pt (deflated 80%)
#   adding: cache/4XGV-A.pt (deflated 82%)
#   adding: cache/6YH3-A.pt (deflated 82%)
#   adding: cache/4LDO-A.pt (deflated 83%)
#   adding: cache/3MWP-A.pt (deflated 83%)
#   adding: cache/1W1U-A.pt (deflated 83%)
#   adding: cache/6O55-A.pt (deflated 79%)
#   adding: cache/6BBO-A.pt (deflated 79%)
#   adding: cache/4QLB-A.pt (deflated 83%)
#   adding: cache/3KIO-A.pt (deflated 81%)
#   adding: cache/3CJR-A.pt (deflated 80%)
#   adding: cache/4HMX-A.pt (deflated 80%)
#   adding: cache/3O59-X.pt (deflated 81%)
#   adding: cache/4EJY-A.pt (deflated 81%)
#   adding: cache/6J2V-A.pt (deflated 82%)
#   adding: cache/3MWC-A.pt (deflated 82%)
#   adding: cache/1BCP-C.pt (deflated 79%)
#   adding: cache/3SD7-A.pt (deflated 80%)
#   adding: cache/2GMN-A.pt (deflated 81%)
#   adding: cache/5Y0N-A.pt (deflated 82%)
#   adding: cache/6QF7-B.pt (deflated 80%)
#   adding: cache/4R8Z-A.pt (deflated 80%)
#   adding: cache/2ROP-A.pt (deflated 79%)
#   adding: cache/1T6N-A.pt (deflated 80%)
#   adding: cache/1FZT-A.pt (deflated 79%)
#   adding: cache/3JYN-A.pt (deflated 81%)
#   adding: cache/1M9U-A.pt (deflated 80%)
#   adding: cache/2NOX-A.pt (deflated 81%)
#   adding: cache/3MTJ-A.pt (deflated 82%)
#   adding: cache/2W68-A.pt (deflated 79%)
#   adding: cache/3L1R-A.pt (deflated 82%)
#   adding: cache/5EF4-A.pt (deflated 82%)
#   adding: cache/1QGC-1.pt (deflated 79%)
#   adding: cache/5ITS-A.pt (deflated 79%)
#   adding: cache/3TI2-A.pt (deflated 80%)
#   adding: cache/5HCK-A.pt (deflated 71%)
#   adding: cache/1RW2-A.pt (deflated 79%)
#   adding: cache/2ZWI-A.pt (deflated 82%)
#   adding: cache/5FSA-A.pt (deflated 83%)
#   adding: cache/4MO2-B.pt (deflated 82%)
#   adding: cache/3TRI-A.pt (deflated 81%)
#   adding: cache/4WZC-A.pt (deflated 79%)
#   adding: cache/1FMB-A.pt (deflated 75%)
#   adding: cache/2V0S-A.pt (deflated 80%)
#   adding: cache/1GTT-A.pt (deflated 82%)
#   adding: cache/5UQE-A.pt (deflated 83%)
#   adding: cache/2EBN-A.pt (deflated 81%)
#   adding: cache/4P7I-C.pt (deflated 65%)
#   adding: cache/3B3J-A.pt (deflated 83%)
#   adding: cache/1EF9-A.pt (deflated 81%)
#   adding: cache/3ZU2-A.pt (deflated 82%)
#   adding: cache/6G18-v.pt (deflated 84%)
#   adding: cache/1VRQ-C.pt (deflated 79%)
#   adding: cache/3GCD-A.pt (deflated 79%)
#   adding: cache/5FA5-A.pt (deflated 83%)
#   adding: cache/2PGW-A.pt (deflated 82%)
#   adding: cache/3OZ2-A.pt (deflated 82%)
#   adding: cache/3HHD-A.pt (deflated 84%)
#   adding: cache/3CQ9-A.pt (deflated 80%)
#   adding: cache/2EKO-A.pt (deflated 78%)
#   adding: cache/1XWI-A.pt (deflated 81%)
#   adding: cache/4JXJ-A.pt (deflated 81%)
#   adding: cache/1WQL-B.pt (deflated 79%)
#   adding: cache/1G0D-A.pt (deflated 83%)
#   adding: cache/1DQU-A.pt (deflated 83%)
#   adding: cache/5IAZ-A.pt (deflated 78%)
#   adding: cache/1WRA-A.pt (deflated 81%)
#   adding: cache/5DLL-A.pt (deflated 84%)
#   adding: cache/6FRV-A.pt (deflated 84%)
#   adding: cache/1XG2-A.pt (deflated 81%)
#   adding: cache/1DIA-A.pt (deflated 81%)
#   adding: cache/4KS7-A.pt (deflated 81%)
#   adding: cache/6PZ2-A.pt (deflated 81%)
#   adding: cache/3UVJ-A.pt (deflated 80%)
#   adding: cache/3REB-B.pt (deflated 72%)
#   adding: cache/3I2H-A.pt (deflated 83%)
#   adding: cache/6OK0-A.pt (deflated 78%)
#   adding: cache/1UEK-A.pt (deflated 81%)
#   adding: cache/5FZO-B.pt (deflated 82%)
#   adding: cache/6QK1-A.pt (deflated 82%)
#   adding: cache/6GFJ-A.pt (deflated 83%)
#   adding: cache/6VYE-A.pt (deflated 81%)
#   adding: cache/4XZW-A.pt (deflated 81%)
#   adding: cache/3ARQ-A.pt (deflated 83%)
#   adding: cache/5L8H-A.pt (deflated 82%)
#   adding: cache/3ABT-A.pt (deflated 83%)
#   adding: cache/3I9V-3.pt (deflated 83%)
#   adding: cache/5Z2G-A.pt (deflated 83%)
#   adding: cache/4OEL-A.pt (deflated 82%)
#   adding: cache/3DC8-A.pt (deflated 83%)
#   adding: cache/3GFO-A.pt (deflated 81%)
#   adding: cache/5Z2X-A.pt (deflated 81%)
#   adding: cache/6SNI-X.pt (deflated 84%)
#   adding: cache/1GQ7-A.pt (deflated 81%)
#   adding: cache/1YOV-B.pt (deflated 83%)
#   adding: cache/1O12-A.pt (deflated 82%)
#   adding: cache/3MVU-A.pt (deflated 80%)
#   adding: cache/4TM8-A.pt (deflated 80%)
#   adding: cache/1NH8-A.pt (deflated 81%)
#   adding: cache/1DMU-A.pt (deflated 81%)
#   adding: cache/4I1U-A.pt (deflated 80%)
#   adding: cache/4HHD-A.pt (deflated 78%)
#   adding: cache/4U9V-B.pt (deflated 79%)
#   adding: cache/2LS6-A.pt (deflated 78%)
#   adding: cache/2P3S-A.pt (deflated 80%)
#   adding: cache/1VIX-A.pt (deflated 82%)
#   adding: cache/5HYG-A.pt (deflated 82%)
#   adding: cache/2PSW-A.pt (deflated 78%)
#   adding: cache/1WG8-A.pt (deflated 81%)
#   adding: cache/4KA7-A.pt (deflated 84%)
#   adding: cache/4GCM-A.pt (deflated 81%)
#   adding: cache/1DCE-A.pt (deflated 83%)
#   adding: cache/3PRM-B.pt (deflated 72%)
#   adding: cache/4PEY-A.pt (deflated 83%)
#   adding: cache/5SVC-A.pt (deflated 83%)
#   adding: cache/1GHE-A.pt (deflated 79%)
#   adding: cache/1ZRH-A.pt (deflated 81%)
#   adding: cache/1WNI-A.pt (deflated 79%)
#   adding: cache/3CDK-B.pt (deflated 80%)
#   adding: cache/6G2J-E.pt (deflated 81%)
#   adding: cache/1JGT-A.pt (deflated 83%)
#   adding: cache/6LP5-A.pt (deflated 79%)
#   adding: cache/3BWV-A.pt (deflated 79%)
#   adding: cache/2JFN-A.pt (deflated 81%)
#   adding: cache/2X0J-A.pt (deflated 81%)
